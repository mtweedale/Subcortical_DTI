# %%
# Download necessary packages
library(ggplot2)
library(psych)
library(dplyr)
library(fmsb)
library(ggradar)
library(plotrix)

# %%
# Extract patient data and patient ROI data
data <- read.csv("~/scratch//tractoflow_hcp_dwi/UKB_WM_Regionwise_Data_allAtlases_allMeasures.csv")
patient_data <- read.csv("~/scratch//tractoflow_hcp_dwi/UKBB_patient_data.csv")

# %%
# Subset data frame based on DTI measure
ad_all_data <- data[data$WM_Measure == 'AD', ]
fa_all_data <- data[data$WM_Measure == 'FA', ]
md_all_data <- data[data$WM_Measure == 'MD', ]
rd_all_data <- data[data$WM_Measure == 'RD', ]

# %%
# Find all unique values per DTI-based data frame
vec1 <- unique(ad_all_data$Subject_ID)
vec2 <- unique(fa_all_data$Subject_ID)
vec3 <- unique(md_all_data$Subject_ID)
vec4 <- unique(rd_all_data$Subject_ID)

# Find the values that are in vec1 but not in vec2
missing_in_df2 <- setdiff(vec1, vec2)

# Find the values that are in vec2 but not in vec1
missing_in_df1 <- setdiff(vec2, vec1)

# Find the values that are in vec3 but not in vec4
missing_in_df4 <- setdiff(vec3, vec4)

# Find the values that are in vec4 but not in vec3
missing_in_df3 <- setdiff(vec4, vec3)

# Combine the missing values from both directions
all_missing_values <- unique(c(missing_in_df1, missing_in_df2, missing_in_df3, missing_in_df4))

# %%
indices_to_remove_df1 <- which(fa_all_data$Subject_ID %in% all_missing_values)

# Remove rows from df1
fa_all_data <- fa_all_data[-indices_to_remove_df1, ]

# Find the indices of rows to be removed in df2
indices_to_remove_df2 <- which(md_all_data$Subject_ID %in% all_missing_values)

# Remove rows from df2
md_all_data <- md_all_data[-indices_to_remove_df2, ]

# Find the indices of rows to be removed in df3
indices_to_remove_df3 <- which(rd_all_data$Subject_ID %in% all_missing_values)

# Remove rows from df3
rd_all_data <- rd_all_data[-indices_to_remove_df3, ]

# %%
# Define variables with relevant ROIs
ad_data <- ad_all_data[c("Subject_ID", "WM_Measure", "left_caudate", "right_caudate", "left_putamen", "right_putamen", "left_nucleus_accumbens", "right_nucleus_accumbens", "left_hippocampus", "right_hippocampus", "left_globus_pallidus_externa", "right_globus_pallidus_externa", "left_globus_pallidus_interna", "right_globus_pallidus_Interna")]
fa_data <- fa_all_data[c("Subject_ID", "WM_Measure", "left_caudate", "right_caudate", "left_putamen", "right_putamen", "left_nucleus_accumbens", "right_nucleus_accumbens", "left_hippocampus", "right_hippocampus", "left_globus_pallidus_externa", "right_globus_pallidus_externa", "left_globus_pallidus_interna", "right_globus_pallidus_Interna")]
md_data <- md_all_data[c("Subject_ID", "WM_Measure", "left_caudate", "right_caudate", "left_putamen", "right_putamen", "left_nucleus_accumbens", "right_nucleus_accumbens", "left_hippocampus", "right_hippocampus", "left_globus_pallidus_externa", "right_globus_pallidus_externa", "left_globus_pallidus_interna", "right_globus_pallidus_Interna")]
rd_data <- rd_all_data[c("Subject_ID", "WM_Measure", "left_caudate", "right_caudate", "left_putamen", "right_putamen", "left_nucleus_accumbens", "right_nucleus_accumbens", "left_hippocampus", "right_hippocampus", "left_globus_pallidus_externa", "right_globus_pallidus_externa", "left_globus_pallidus_interna", "right_globus_pallidus_Interna")]

# %%
# Calculate average value for each ROI for AD data
ad_data$caudate <- rowMeans(ad_data[c("left_caudate", "right_caudate")], na.rm = TRUE)
ad_data$putamen <- rowMeans(ad_data[c("left_putamen", "right_putamen")], na.rm = TRUE)
ad_data$nacc <- rowMeans(ad_data[c("left_nucleus_accumbens", "right_nucleus_accumbens")], na.rm = TRUE)
ad_data$hippocampus <- rowMeans(ad_data[c("left_hippocampus", "right_hippocampus")], na.rm = TRUE)
ad_data$pallidum <- rowMeans(ad_data[c("left_globus_pallidus_externa", "right_globus_pallidus_externa", "left_globus_pallidus_interna", "right_globus_pallidus_Interna")], na.rm = TRUE)

# Calculate average value for each ROI for FA data
fa_data$caudate <- rowMeans(fa_data[c("left_caudate", "right_caudate")], na.rm = TRUE)
fa_data$putamen <- rowMeans(fa_data[c("left_putamen", "right_putamen")], na.rm = TRUE)
fa_data$nacc <- rowMeans(fa_data[c("left_nucleus_accumbens", "right_nucleus_accumbens")], na.rm = TRUE)
fa_data$hippocampus <- rowMeans(fa_data[c("left_hippocampus", "right_hippocampus")], na.rm = TRUE)
fa_data$pallidum <- rowMeans(fa_data[c("left_globus_pallidus_externa", "right_globus_pallidus_externa", "left_globus_pallidus_interna", "right_globus_pallidus_Interna")], na.rm = TRUE)

# Calculate average value for each ROI for MD data
md_data$caudate <- rowMeans(md_data[c("left_caudate", "right_caudate")], na.rm = TRUE)
md_data$putamen <- rowMeans(md_data[c("left_putamen", "right_putamen")], na.rm = TRUE)
md_data$nacc <- rowMeans(md_data[c("left_nucleus_accumbens", "right_nucleus_accumbens")], na.rm = TRUE)
md_data$hippocampus <- rowMeans(md_data[c("left_hippocampus", "right_hippocampus")], na.rm = TRUE)
md_data$pallidum <- rowMeans(md_data[c("left_globus_pallidus_externa", "right_globus_pallidus_externa", "left_globus_pallidus_interna", "right_globus_pallidus_Interna")], na.rm = TRUE)

# Calculate average value for each ROI for RD data
rd_data$caudate <- rowMeans(rd_data[c("left_caudate", "right_caudate")], na.rm = TRUE)
rd_data$putamen <- rowMeans(rd_data[c("left_putamen", "right_putamen")], na.rm = TRUE)
rd_data$nacc <- rowMeans(rd_data[c("left_nucleus_accumbens", "right_nucleus_accumbens")], na.rm = TRUE)
rd_data$hippocampus <- rowMeans(rd_data[c("left_hippocampus", "right_hippocampus")], na.rm = TRUE)
rd_data$pallidum <- rowMeans(rd_data[c("left_globus_pallidus_externa", "right_globus_pallidus_externa", "left_globus_pallidus_interna", "right_globus_pallidus_Interna")], na.rm = TRUE)

# %%
# Remove outliers for AD data
Q3_c=as.numeric(quantile(ad_data$caudate,0.75, na.rm=TRUE))
Q1_c=as.numeric(quantile(ad_data$caudate,0.25, na.rm=TRUE))
upper_c=Q3_c+(2.2*(Q3_c-Q1_c))
lower_c=Q1_c-(2.2*(Q3_c-Q1_c))
Q3_pu=as.numeric(quantile(ad_data$putamen,0.75, na.rm=TRUE))
Q1_pu=as.numeric(quantile(ad_data$putamen,0.25, na.rm=TRUE))
upper_pu=Q3_pu+(2.2*(Q3_pu-Q1_pu))
lower_pu=Q1_pu-(2.2*(Q3_pu-Q1_pu))
Q3_n=as.numeric(quantile(ad_data$nacc,0.75, na.rm=TRUE))
Q1_n=as.numeric(quantile(ad_data$nacc,0.25, na.rm=TRUE))
upper_n=Q3_n+(2.2*(Q3_n-Q1_n))
lower_n=Q1_n-(2.2*(Q3_n-Q1_n))
Q3_h=as.numeric(quantile(ad_data$hippocampus,0.75, na.rm=TRUE))
Q1_h=as.numeric(quantile(ad_data$hippocampus,0.25, na.rm=TRUE))
upper_h=Q3_h+(2.2*(Q3_h-Q1_h))
lower_h=Q1_h-(2.2*(Q3_h-Q1_h))
Q3_pa=as.numeric(quantile(ad_data$pallidum,0.75, na.rm=TRUE))
Q1_pa=as.numeric(quantile(ad_data$pallidum,0.25, na.rm=TRUE))
upper_pa=Q3_pa+(2.2*(Q3_pa-Q1_pa))
lower_pa=Q1_pa-(2.2*(Q3_pa-Q1_pa))
ad_data$caudate[ad_data$caudate<lower_c]=NA
ad_data$caudate[ad_data$caudate>upper_c]=NA
ad_data$caudate[ad_data$putamen<lower_pu]=NA
ad_data$caudate[ad_data$putamen>upper_pu]=NA
ad_data$caudate[ad_data$nacc<lower_n]=NA
ad_data$caudate[ad_data$nacc>upper_n]=NA
ad_data$caudate[ad_data$hippocampus<lower_h]=NA
ad_data$caudate[ad_data$hippocampus>upper_h]=NA
ad_data$caudate[ad_data$pallidum<lower_pa]=NA
ad_data$caudate[ad_data$pallidum>upper_pa]=NA

# Remove outliers for FA data
Q3_c=as.numeric(quantile(fa_data$caudate,0.75, na.rm=TRUE))
Q1_c=as.numeric(quantile(fa_data$caudate,0.25, na.rm=TRUE))
upper_c=Q3_c+(2.2*(Q3_c-Q1_c))
lower_c=Q1_c-(2.2*(Q3_c-Q1_c))
Q3_pu=as.numeric(quantile(fa_data$putamen,0.75, na.rm=TRUE))
Q1_pu=as.numeric(quantile(fa_data$putamen,0.25, na.rm=TRUE))
upper_pu=Q3_pu+(2.2*(Q3_pu-Q1_pu))
lower_pu=Q1_pu-(2.2*(Q3_pu-Q1_pu))
Q3_n=as.numeric(quantile(fa_data$nacc,0.75, na.rm=TRUE))
Q1_n=as.numeric(quantile(fa_data$nacc,0.25, na.rm=TRUE))
upper_n=Q3_n+(2.2*(Q3_n-Q1_n))
lower_n=Q1_n-(2.2*(Q3_n-Q1_n))
Q3_h=as.numeric(quantile(fa_data$hippocampus,0.75, na.rm=TRUE))
Q1_h=as.numeric(quantile(fa_data$hippocampus,0.25, na.rm=TRUE))
upper_h=Q3_h+(2.2*(Q3_h-Q1_h))
lower_h=Q1_h-(2.2*(Q3_h-Q1_h))
Q3_pa=as.numeric(quantile(fa_data$pallidum,0.75, na.rm=TRUE))
Q1_pa=as.numeric(quantile(fa_data$pallidum,0.25, na.rm=TRUE))
upper_pa=Q3_pa+(2.2*(Q3_pa-Q1_pa))
lower_pa=Q1_pa-(2.2*(Q3_pa-Q1_pa))
fa_data$caudate[fa_data$caudate<lower_c]=NA
fa_data$caudate[fa_data$caudate>upper_c]=NA
fa_data$caudate[fa_data$putamen<lower_pu]=NA
fa_data$caudate[fa_data$putamen>upper_pu]=NA
fa_data$caudate[fa_data$nacc<lower_n]=NA
fa_data$caudate[fa_data$nacc>upper_n]=NA
fa_data$caudate[fa_data$hippocampus<lower_h]=NA
fa_data$caudate[fa_data$hippocampus>upper_h]=NA
fa_data$caudate[fa_data$pallidum<lower_pa]=NA
fa_data$caudate[fa_data$pallidum>upper_pa]=NA

# Remove outliers for MD data
Q3_c=as.numeric(quantile(md_data$caudate,0.75, na.rm=TRUE))
Q1_c=as.numeric(quantile(md_data$caudate,0.25, na.rm=TRUE))
upper_c=Q3_c+(2.2*(Q3_c-Q1_c))
lower_c=Q1_c-(2.2*(Q3_c-Q1_c))
Q3_pu=as.numeric(quantile(md_data$putamen,0.75, na.rm=TRUE))
Q1_pu=as.numeric(quantile(md_data$putamen,0.25, na.rm=TRUE))
upper_pu=Q3_pu+(2.2*(Q3_pu-Q1_pu))
lower_pu=Q1_pu-(2.2*(Q3_pu-Q1_pu))
Q3_n=as.numeric(quantile(md_data$nacc,0.75, na.rm=TRUE))
Q1_n=as.numeric(quantile(md_data$nacc,0.25, na.rm=TRUE))
upper_n=Q3_n+(2.2*(Q3_n-Q1_n))
lower_n=Q1_n-(2.2*(Q3_n-Q1_n))
Q3_h=as.numeric(quantile(md_data$hippocampus,0.75, na.rm=TRUE))
Q1_h=as.numeric(quantile(md_data$hippocampus,0.25, na.rm=TRUE))
upper_h=Q3_h+(2.2*(Q3_h-Q1_h))
lower_h=Q1_h-(2.2*(Q3_h-Q1_h))
Q3_pa=as.numeric(quantile(md_data$pallidum,0.75, na.rm=TRUE))
Q1_pa=as.numeric(quantile(md_data$pallidum,0.25, na.rm=TRUE))
upper_pa=Q3_pa+(2.2*(Q3_pa-Q1_pa))
lower_pa=Q1_pa-(2.2*(Q3_pa-Q1_pa))
md_data$caudate[md_data$caudate<lower_c]=NA
md_data$caudate[md_data$caudate>upper_c]=NA
md_data$caudate[md_data$putamen<lower_pu]=NA
md_data$caudate[md_data$putamen>upper_pu]=NA
md_data$caudate[md_data$nacc<lower_n]=NA
md_data$caudate[md_data$nacc>upper_n]=NA
md_data$caudate[md_data$hippocampus<lower_h]=NA
md_data$caudate[md_data$hippocampus>upper_h]=NA
md_data$caudate[md_data$pallidum<lower_pa]=NA
md_data$caudate[md_data$pallidum>upper_pa]=NA

# Remove outliers for RD data
Q3_c=as.numeric(quantile(rd_data$caudate,0.75, na.rm=TRUE))
Q1_c=as.numeric(quantile(rd_data$caudate,0.25, na.rm=TRUE))
upper_c=Q3_c+(2.2*(Q3_c-Q1_c))
lower_c=Q1_c-(2.2*(Q3_c-Q1_c))
Q3_pu=as.numeric(quantile(rd_data$putamen,0.75, na.rm=TRUE))
Q1_pu=as.numeric(quantile(rd_data$putamen,0.25, na.rm=TRUE))
upper_pu=Q3_pu+(2.2*(Q3_pu-Q1_pu))
lower_pu=Q1_pu-(2.2*(Q3_pu-Q1_pu))
Q3_n=as.numeric(quantile(rd_data$nacc,0.75, na.rm=TRUE))
Q1_n=as.numeric(quantile(rd_data$nacc,0.25, na.rm=TRUE))
upper_n=Q3_n+(2.2*(Q3_n-Q1_n))
lower_n=Q1_n-(2.2*(Q3_n-Q1_n))
Q3_h=as.numeric(quantile(rd_data$hippocampus,0.75, na.rm=TRUE))
Q1_h=as.numeric(quantile(rd_data$hippocampus,0.25, na.rm=TRUE))
upper_h=Q3_h+(2.2*(Q3_h-Q1_h))
lower_h=Q1_h-(2.2*(Q3_h-Q1_h))
Q3_pa=as.numeric(quantile(rd_data$pallidum,0.75, na.rm=TRUE))
Q1_pa=as.numeric(quantile(rd_data$pallidum,0.25, na.rm=TRUE))
upper_pa=Q3_pa+(2.2*(Q3_pa-Q1_pa))
lower_pa=Q1_pa-(2.2*(Q3_pa-Q1_pa))
rd_data$caudate[rd_data$caudate<lower_c]=NA
rd_data$caudate[rd_data$caudate>upper_c]=NA
rd_data$caudate[rd_data$putamen<lower_pu]=NA
rd_data$caudate[rd_data$putamen>upper_pu]=NA
rd_data$caudate[rd_data$nacc<lower_n]=NA
rd_data$caudate[rd_data$nacc>upper_n]=NA
rd_data$caudate[rd_data$hippocampus<lower_h]=NA
rd_data$caudate[rd_data$hippocampus>upper_h]=NA
rd_data$caudate[rd_data$pallidum<lower_pa]=NA
rd_data$caudate[rd_data$pallidum>upper_pa]=NA

# %%
# Rename column names to patient DTI data frames
colnames(patient_data)[colnames(patient_data) == "eid"] <- "Subject_ID"

# %%
# Merge DTI data frames with relevant patient variables
subj_data <- patient_data[c("Subject_ID", "sex_31.0.0", "age_when_attended_assessment_centre_21003.2.0", "volume_of_estimatedtotalintracranial_whole_brain_26521.2.0", "uk_biobank_assessment_centre_54.2.0", "mean_tfmri_head_motion_averaged_across_space_and_time_points_25742.2.0", "mean_rfmri_head_motion_averaged_across_space_and_time_points_25741.2.0", "date_of_attending_assessment_centre_53.2.0", "body_mass_index_bmi_21001.2.0", "c.reactive_protein_30710.0.0", "glucose_30740.0.0", "glycated_haemoglobin_hba1c_30750.0.0", "cholesterol_30690.0.0", "hdl_cholesterol_30760.0.0", "ldl_direct_30780.0.0", "triglycerides_30870.0.0", "systolic_blood_pressure_automated_reading_4080.0.1", "diastolic_blood_pressure_automated_reading_4079.0.1")]
ad_subj_data=merge(subj_data, ad_data)
fa_subj_data=merge(subj_data, fa_data)
md_subj_data=merge(subj_data, md_data)
rd_subj_data=merge(subj_data, rd_data)

# %%
# Extract previously calculated hypothalamus data from scatter_plots_UKBB.ipynb
hypo_ad <- read.csv("~/linear_regression/UKBB_ad_data.csv")
hypo_fa <- read.csv("~/linear_regression/UKBB_fa_data.csv")
hypo_md <- read.csv("~/linear_regression/UKBB_md_data.csv")
hypo_rd <- read.csv("~/linear_regression/UKBB_rd_data.csv")

# %%
indices_to_remove_df1 <- which(hypo_fa$eid %in% all_missing_values)

# Remove rows from df1
hypo_fa <- hypo_fa[-indices_to_remove_df1, ]

# Find the indices of rows to be removed in df2
indices_to_remove_df2 <- which(hypo_md$eid %in% all_missing_values)

# Remove rows from df2
hypo_md <- hypo_md[-indices_to_remove_df2, ]

# Find the indices of rows to be removed in df3
indices_to_remove_df3 <- which(hypo_rd$eid %in% all_missing_values)

# Remove rows from df3
hypo_rd <- hypo_rd[-indices_to_remove_df3, ]

# %%
# Add hypothalamic values to subject data frames
ad_subj_data$full_hypo <- hypo_ad$full_hypo
fa_subj_data$full_hypo <- hypo_fa$full_hypo
md_subj_data$full_hypo <- hypo_md$full_hypo
rd_subj_data$full_hypo <- hypo_rd$full_hypo
# Out:
# Error in `$<-.data.frame`(`*tmp*`, full_hypo, value = numeric(0)): replacement has 0 rows, data has 26242
# Traceback:
#
# 1. `$<-`(`*tmp*`, full_hypo, value = numeric(0))
# 2. `$<-.data.frame`(`*tmp*`, full_hypo, value = numeric(0))
# 3. stop(sprintf(ngettext(N, "replacement has %d row, data has %d",
#  .     "replacement has %d rows, data has %d"), N, nrows), domain = NA)

# %%
# Remove outliers for hypothalamic AD data
Q3=as.numeric(quantile(ad_subj_data$full_hypo,0.75, na.rm=TRUE))
Q1=as.numeric(quantile(ad_subj_data$full_hypo,0.25, na.rm=TRUE))
upper=Q3+(2.2*(Q3-Q1))
lower=Q1-(2.2*(Q3-Q1))
ad_subj_data$full_hypo[ad_subj_data$full_hypo<lower]=NA
ad_subj_data$full_hypo[ad_subj_data$full_hypo>upper]=NA

# Remove outliers for hypothalamic Fa data
Q3=as.numeric(quantile(fa_subj_data$full_hypo,0.75, na.rm=TRUE))
Q1=as.numeric(quantile(fa_subj_data$full_hypo,0.25, na.rm=TRUE))
upper=Q3+(2.2*(Q3-Q1))
lower=Q1-(2.2*(Q3-Q1))
fa_subj_data$full_hypo[fa_subj_data$full_hypo<lower]=NA
fa_subj_data$full_hypo[fa_subj_data$full_hypo>upper]=NA

# Remove outliers for hypothalamic MD data
Q3=as.numeric(quantile(md_subj_data$full_hypo,0.75, na.rm=TRUE))
Q1=as.numeric(quantile(md_subj_data$full_hypo,0.25, na.rm=TRUE))
upper=Q3+(2.2*(Q3-Q1))
lower=Q1-(2.2*(Q3-Q1))
md_subj_data$full_hypo[md_subj_data$full_hypo<lower]=NA
md_subj_data$full_hypo[md_subj_data$full_hypo>upper]=NA

# Remove outliers for hypothalamic RD data
Q3=as.numeric(quantile(rd_subj_data$full_hypo,0.75, na.rm=TRUE))
Q1=as.numeric(quantile(rd_subj_data$full_hypo,0.25, na.rm=TRUE))
upper=Q3+(2.2*(Q3-Q1))
lower=Q1-(2.2*(Q3-Q1))
rd_subj_data$full_hypo[rd_subj_data$full_hypo<lower]=NA
rd_subj_data$full_hypo[rd_subj_data$full_hypo>upper]=NA
# Out:
# Error in `$<-.data.frame`(`*tmp*`, full_hypo, value = logical(0)): replacement has 0 rows, data has 26242
# Traceback:
#
# 1. `$<-`(`*tmp*`, full_hypo, value = logical(0))
# 2. `$<-.data.frame`(`*tmp*`, full_hypo, value = logical(0))
# 3. stop(sprintf(ngettext(N, "replacement has %d row, data has %d",
#  .     "replacement has %d rows, data has %d"), N, nrows), domain = NA)

# %%
# Write CSV files for DTI data frames
write.csv(ad_subj_data, "~/scratch/tractoflow_hcp_dwi/linear_regression/UKBB_ad_data_other.csv")
write.csv(fa_subj_data, "~/scratch/tractoflow_hcp_dwi/linear_regression/UKBB_fa_data_other.csv")
write.csv(md_subj_data, "~/scratch/tractoflow_hcp_dwi/linear_regression/UKBB_md_data_other.csv")
write.csv(rd_subj_data, "~/scratch/tractoflow_hcp_dwi/linear_regression/UKBB_rd_data_other.csv")

# %%
# It takes a while to load UKB_WM_Regionwise_Data_allAtlases_allMeasures.csv,
# so if the code needs to edited you can start from here by redefining the
# variables from the prewritten CSV files
ad_subj_data <- read.csv("~/linear_regression/UKBB_ad_data_other.csv")
fa_subj_data <- read.csv("~/linear_regression/UKBB_fa_data_other.csv")
md_subj_data <- read.csv("~/linear_regression/UKBB_md_data_other.csv")
rd_subj_data <- read.csv("~/linear_regression/UKBB_rd_data_other.csv")

# %%
ad_subj_data$gl
# Out:
#       X     Subject_ID sex_31.0.0 age_when_attended_assessment_centre_21003.2.0
# 1      1    1000394    Male       68
# 2      2    1000635    Male       67
# 3      3    1001159    Female     49
# 4      4    1001329    Male       69
# 5      5    1001337    Male       65
# 6      6    1001523    Male       68
# 7      7    1001598    Female     51
# 8      8    1001645    Female     69
# 9      9    1002545    Male       72
# 10    10    1002612    Male       67
# 11    11    1002664    Female     65
# 12    12    1002924    Female     54
# 13    13    1003385    Female     62
# 14    14    1003860    Female     70
# 15    15    1003965    Male       68
# 16    16    1004084    Male       70
# 17    17    1004376    Male       63
# 18    18    1004436    Male       74
# 19    19    1004785    Male       69
# 20    20    1005096    Male       57
# 21    21    1005216    Female     61
# 22    22    1005926    Female     57
# 23    23    1006706    Male       65
# 24    24    1006934    Female     55
# 25    25    1007323    Female     70
# 26    26    1007398    Male       70
# 27    27    1007609    Female     71
# 28    28    1007767    Male       71
# 29    29    1007876    Male       68
# 30    30    1007947    Female     60
# ⋮     ⋮     ⋮          ⋮          ⋮
# 26213 26213 6020386    Male       76
# 26214 26214 6020518    Female     61
# 26215 26215 6020551    Female     52
# 26216 26216 6020585    Female     78
# 26217 26217 6020626    Male       55
# 26218 26218 6021164    Female     50
# 26219 26219 6021255    Male       69
# 26220 26220 6021263    Male       57
# 26221 26221 6021272    Male       72
# 26222 26222 6021362    Male       79
# 26223 26223 6021433    Male       66
# 26224 26224 6021516    Male       71
# 26225 26225 6021793    Female     60
# 26226 26226 6022064    Female     60
# 26227 26227 6022167    Female     54
# 26228 26228 6022218    Male       75
# 26229 26229 6022307    Female     62
# 26230 26230 6023009    Male       51
# 26231 26231 6023026    Male       56
# 26232 26232 6023060    Female     52
# 26233 26233 6023168    Female     65
# 26234 26234 6023881    Male       64
# 26235 26235 6023918    Female     58
# 26236 26236 6024041    Male       69
# 26237 26237 6024303    Male       64
# 26238 26238 6024476    Female     58
# 26239 26239 6024583    Male       60
# 26240 26240 6024843    Female     63
# 26241 26241 6024895    Male       68
# 26242 26242 6024935    Male       58
#       volume_of_estimatedtotalintracranial_whole_brain_26521.2.0
# 1     1873620
# 2     1803160
# 3     1568080
# 4     1545120
# 5     1594040
# 6     1724190
# 7     1569210
# 8     1495080
# 9     1706860
# 10    1679210
# 11    1453760
# 12    1570840
# 13    1828040
# 14    1389090
# 15    1424470
# 16    1470610
# 17    1744990
# 18    1663010
# 19    1579850
# 20    1962000
# 21    1405680
# 22    1481070
# 23    1540200
# 24    1368520
# 25    1415580
# 26    1794530
# 27    1336650
# 28    1787830
# 29    1583010
# 30    1375640
# ⋮     ⋮
# 26213 1718000
# 26214 1487480
# 26215 1669220
# 26216 1578930
# 26217 1644380
# 26218 1628210
# 26219 1881450
# 26220 1822790
# 26221 1992230
# 26222 1517980
# 26223 1830250
# 26224 1828930
# 26225 1616290
# 26226 1626990
# 26227 1138530
# 26228 1677710
# 26229 1209800
# 26230 1652010
# 26231 1576300
# 26232 1689770
# 26233 1675700
# 26234 1498760
# 26235 1501140
# 26236 1754120
# 26237 1569800
# 26238 1235280
# 26239 1675390
# 26240 1394820
# 26241 1477100
# 26242 1811920
#       uk_biobank_assessment_centre_54.2.0
# 1     Cheadle (imaging)
# 2     Newcastle (imaging)
# 3     Cheadle (imaging)
# 4     Cheadle (imaging)
# 5     Cheadle (imaging)
# 6     Reading (imaging)
# 7     Newcastle (imaging)
# 8     Newcastle (imaging)
# 9     Cheadle (imaging)
# 10    Reading (imaging)
# 11    Cheadle (imaging)
# 12    Cheadle (imaging)
# 13    Reading (imaging)
# 14    Cheadle (imaging)
# 15    Cheadle (imaging)
# 16    Newcastle (imaging)
# 17    Reading (imaging)
# 18    Reading (imaging)
# 19    Newcastle (imaging)
# 20    Cheadle (imaging)
# 21    Cheadle (imaging)
# 22    Newcastle (imaging)
# 23    Newcastle (imaging)
# 24    Cheadle (imaging)
# 25    Cheadle (imaging)
# 26    Cheadle (imaging)
# 27    Cheadle (imaging)
# 28    Cheadle (imaging)
# 29    Cheadle (imaging)
# 30    Cheadle (imaging)
# ⋮     ⋮
# 26213 Cheadle (imaging)
# 26214 Newcastle (imaging)
# 26215 Newcastle (imaging)
# 26216 Newcastle (imaging)
# 26217 Cheadle (imaging)
# 26218 Cheadle (imaging)
# 26219 Reading (imaging)
# 26220 Cheadle (imaging)
# 26221 Cheadle (imaging)
# 26222 Newcastle (imaging)
# 26223 Cheadle (imaging)
# 26224 Newcastle (imaging)
# 26225 Reading (imaging)
# 26226 Cheadle (imaging)
# 26227 Newcastle (imaging)
# 26228 Cheadle (imaging)
# 26229 Newcastle (imaging)
# 26230 Cheadle (imaging)
# 26231 Cheadle (imaging)
# 26232 Reading (imaging)
# 26233 Cheadle (imaging)
# 26234 Cheadle (imaging)
# 26235 Newcastle (imaging)
# 26236 Cheadle (imaging)
# 26237 Cheadle (imaging)
# 26238 Cheadle (imaging)
# 26239 Cheadle (imaging)
# 26240 Newcastle (imaging)
# 26241 Cheadle (imaging)
# 26242 Cheadle (imaging)
#       mean_tfmri_head_motion_averaged_across_space_and_time_points_25742.2.0
# 1     0.1290760
# 2     0.2776660
# 3            NA
# 4     0.2716030
# 5     0.1121660
# 6            NA
# 7            NA
# 8     0.1400690
# 9     0.1723060
# 10    0.1429010
# 11           NA
# 12    0.1111480
# 13           NA
# 14           NA
# 15    0.0947005
# 16           NA
# 17           NA
# 18    0.1367630
# 19    0.1150570
# 20    0.1086570
# 21    0.1275020
# 22    0.1132830
# 23           NA
# 24    0.2269700
# 25           NA
# 26    0.1746090
# 27    0.1498770
# 28    0.1265740
# 29    0.1692990
# 30    0.2044460
# ⋮     ⋮
# 26213 0.1585760
# 26214 0.1705190
# 26215 0.1066510
# 26216        NA
# 26217 0.0638956
# 26218 0.1211940
# 26219 0.1170710
# 26220 0.0803515
# 26221 0.1594320
# 26222        NA
# 26223 0.1750350
# 26224 0.2717420
# 26225 0.1229510
# 26226        NA
# 26227 0.1370760
# 26228 0.0907148
# 26229 0.0856143
# 26230        NA
# 26231 0.1549610
# 26232        NA
# 26233 0.1020830
# 26234 0.1313730
# 26235 0.0993363
# 26236 0.1784940
# 26237        NA
# 26238 0.2453600
# 26239 0.1326110
# 26240 0.1636040
# 26241 0.1116250
# 26242 0.1182370
#       mean_rfmri_head_motion_averaged_across_space_and_time_points_25741.2.0
# 1     0.0972601
# 2            NA
# 3     0.0848231
# 4     0.1222250
# 5     0.1247030
# 6     0.0606534
# 7     0.1821780
# 8     0.0925638
# 9     0.1297470
# 10    0.0877905
# 11    0.0744286
# 12    0.1066170
# 13    0.1127840
# 14    0.0780450
# 15    0.0716359
# 16           NA
# 17    0.1382870
# 18    0.1591660
# 19    0.1328010
# 20    0.1114900
# 21    0.0754326
# 22    0.0851888
# 23    0.1239670
# 24    0.1839780
# 25    0.1393750
# 26    0.1873770
# 27    0.1056510
# 28    0.1027640
# 29    0.1233520
# 30    0.1799320
# ⋮     ⋮
# 26213 0.1289790
# 26214 0.1033370
# 26215 0.0941861
# 26216 0.1187620
# 26217 0.0714557
# 26218 0.0897510
# 26219 0.0932508
# 26220 0.0822285
# 26221 0.1091770
# 26222 0.2406080
# 26223 0.0881632
# 26224 0.1671630
# 26225 0.1040790
# 26226 0.0790769
# 26227 0.0958113
# 26228 0.1125160
# 26229 0.0810455
# 26230 0.1387080
# 26231 0.1242490
# 26232 0.1682900
# 26233 0.0969335
# 26234 0.0801955
# 26235 0.0834046
# 26236 0.1217140
# 26237        NA
# 26238 0.1858600
# 26239 0.1239120
# 26240 0.1460620
# 26241 0.0824514
# 26242 0.1061750
#       date_of_attending_assessment_centre_53.2.0 body_mass_index_bmi_21001.2.0
# 1     2019-01-17                                 25.9879
# 2     2017-12-21                                      NA
# 3     2016-12-10                                 37.0755
# 4     2018-04-25                                 28.6979
# 5     2018-12-14                                 25.8546
# 6     2019-03-30                                 23.6854
# 7     2019-05-21                                      NA
# 8     2018-05-03                                 20.2153
# 9     2019-05-06                                 24.9022
# 10    2019-06-17                                 28.9686
# 11    2018-10-03                                 26.3158
# 12    2017-11-27                                 32.0674
# 13    2019-10-03                                      NA
# 14    2017-03-11                                 23.5355
# 15    2018-03-26                                 25.5145
# 16    2017-05-23                                 34.5721
# 17    2018-09-03                                 21.8722
# 18    2019-10-03                                 28.1175
# 19    2019-07-18                                 26.2170
# 20    2017-02-08                                 28.8970
# 21    2016-11-30                                 23.1142
# 22    2018-05-04                                 21.8493
# 23    2019-08-10                                      NA
# 24    2019-05-10                                 29.6681
# 25    2018-04-23                                 24.9909
# 26    2016-09-02                                 28.3604
# 27    2018-01-03                                 24.9200
# 28    2016-10-04                                 23.3572
# 29    2015-11-10                                 24.9713
# 30    2016-04-23                                 36.4481
# ⋮     ⋮                                          ⋮
# 26213 2015-07-15                                 23.7894
# 26214 2018-10-08                                 30.3288
# 26215 2018-11-03                                      NA
# 26216 2018-09-20                                 33.8756
# 26217 2016-12-01                                 20.8897
# 26218 2016-12-06                                 29.7339
# 26219 2018-07-23                                 24.1357
# 26220 2017-12-18                                 23.5989
# 26221 2018-04-06                                 26.7803
# 26222 2019-07-02                                 27.7254
# 26223 2016-04-15                                 25.2482
# 26224 2019-08-07                                 30.9155
# 26225 2019-04-13                                 28.7455
# 26226 2019-07-01                                 21.1668
# 26227 2019-08-03                                 29.0234
# 26228 2016-03-09                                 25.0341
# 26229 2017-09-28                                      NA
# 26230 2018-06-16                                 31.9673
# 26231 2015-11-06                                 27.7117
# 26232 2019-04-27                                 29.1742
# 26233 2017-03-22                                 20.5235
# 26234 2017-05-26                                 25.7929
# 26235 2018-01-30                                      NA
# 26236 2016-09-14                                 25.3440
# 26237 2018-05-04                                 35.1648
# 26238 2019-01-18                                      NA
# 26239 2016-07-19                                 28.8758
# 26240 2019-10-30                                 24.9960
# 26241 2018-09-28                                 26.9886
# 26242 2018-01-15                                 25.0927
#       ⋯ left_globus_pallidus_externa right_globus_pallidus_externa
# 1     ⋯ 0.001009                     0.000969
# 2     ⋯ 0.000879                     0.000960
# 3     ⋯ 0.000843                     0.000881
# 4     ⋯ 0.001054                     0.001110
# 5     ⋯ 0.000779                     0.000820
# 6     ⋯ 0.000806                     0.000975
# 7     ⋯ 0.000779                     0.000883
# 8     ⋯ 0.000938                     0.000942
# 9     ⋯ 0.000954                     0.000992
# 10    ⋯ 0.000792                     0.000944
# 11    ⋯ 0.000832                     0.000892
# 12    ⋯ 0.001034                     0.001016
# 13    ⋯ 0.000878                     0.000897
# 14    ⋯ 0.000952                     0.001006
# 15    ⋯ 0.001523                     0.001598
# 16    ⋯ 0.001185                     0.001336
# 17    ⋯ 0.000870                     0.000962
# 18    ⋯ 0.000858                     0.000906
# 19    ⋯ 0.000970                     0.001021
# 20    ⋯ 0.000908                     0.000955
# 21    ⋯ 0.000858                     0.000951
# 22    ⋯ 0.000844                     0.000922
# 23    ⋯ 0.001072                     0.001098
# 24    ⋯ 0.000795                     0.000883
# 25    ⋯ 0.000946                     0.000992
# 26    ⋯ 0.000966                     0.000983
# 27    ⋯ 0.000968                     0.000981
# 28    ⋯ 0.000953                     0.000928
# 29    ⋯ 0.000872                     0.000887
# 30    ⋯ 0.000967                     0.000939
# ⋮     ⋱ ⋮                            ⋮
# 26213 ⋯ 0.000903                     0.000957
# 26214 ⋯ 0.000997                     0.001078
# 26215 ⋯ 0.000914                     0.000995
# 26216 ⋯ 0.000930                     0.000920
# 26217 ⋯ 0.000982                     0.001043
# 26218 ⋯ 0.000821                     0.000874
# 26219 ⋯ 0.000743                     0.000905
# 26220 ⋯ 0.000833                     0.000920
# 26221 ⋯ 0.000806                     0.000912
# 26222 ⋯ 0.000920                     0.000922
# 26223 ⋯ 0.000917                     0.000958
# 26224 ⋯ 0.000862                     0.000869
# 26225 ⋯ 0.000873                     0.000922
# 26226 ⋯ 0.000894                     0.000922
# 26227 ⋯ 0.000895                     0.000905
# 26228 ⋯ 0.000897                     0.000950
# 26229 ⋯ 0.000868                     0.000862
# 26230 ⋯ 0.000876                     0.000905
# 26231 ⋯ 0.000914                     0.000912
# 26232 ⋯ 0.000989                     0.001043
# 26233 ⋯ 0.000964                     0.000974
# 26234 ⋯ 0.000902                     0.000922
# 26235 ⋯ 0.000830                     0.000883
# 26236 ⋯ 0.000996                     0.000987
# 26237 ⋯ 0.000938                     0.000995
# 26238 ⋯ 0.000780                     0.000893
# 26239 ⋯ 0.000901                     0.000942
# 26240 ⋯ 0.000907                     0.000941
# 26241 ⋯ 0.000866                     0.000979
# 26242 ⋯ 0.000904                     0.000905
#       left_globus_pallidus_interna right_globus_pallidus_Interna caudate
# 1     0.001011                     0.001014                      0.0014510
# 2     0.000973                     0.001035                      0.0011450
# 3     0.000907                     0.000920                      0.0009780
# 4     0.001189                     0.001232                             NA
# 5     0.000877                     0.000870                      0.0012440
# 6     0.000791                     0.000860                      0.0010915
# 7     0.000859                     0.000849                      0.0014430
# 8     0.000897                     0.000904                             NA
# 9     0.000979                     0.000942                      0.0012305
# 10    0.000817                     0.000980                      0.0012165
# 11    0.000815                     0.000887                             NA
# 12    0.001256                     0.001251                             NA
# 13    0.000852                     0.000919                      0.0010265
# 14    0.000920                     0.000983                      0.0010810
# 15    0.001357                     0.001300                             NA
# 16    0.001178                     0.001611                             NA
# 17    0.000880                     0.001003                      0.0013745
# 18    0.000884                     0.000881                      0.0014390
# 19    0.001072                     0.001135                      0.0010265
# 20    0.000898                     0.001027                      0.0010090
# 21    0.000821                     0.000941                      0.0010135
# 22    0.000899                     0.000920                      0.0009660
# 23    0.001188                     0.001198                             NA
# 24    0.000833                     0.000914                             NA
# 25    0.000948                     0.000994                      0.0011010
# 26    0.000989                     0.000980                      0.0011715
# 27    0.000938                     0.000999                      0.0008980
# 28    0.001071                     0.001037                      0.0012735
# 29    0.000870                     0.000925                      0.0014475
# 30    0.000886                     0.000896                      0.0009770
# ⋮     ⋮                            ⋮                             ⋮
# 26213 0.000986                     0.001006                             NA
# 26214 0.001130                     0.001275                      0.0010660
# 26215 0.000969                     0.000992                      0.0009310
# 26216 0.000968                     0.000984                      0.0012800
# 26217 0.001179                     0.001115                      0.0009335
# 26218 0.000901                     0.000942                      0.0009175
# 26219 0.000778                     0.000840                      0.0012905
# 26220 0.000864                     0.000961                      0.0014515
# 26221 0.000887                     0.000965                      0.0010290
# 26222 0.000945                     0.000963                      0.0014130
# 26223 0.000930                     0.000962                      0.0010920
# 26224 0.000972                     0.000915                      0.0010935
# 26225 0.000970                     0.001007                      0.0011805
# 26226 0.000882                     0.000946                      0.0011425
# 26227 0.000915                     0.000941                      0.0010185
# 26228 0.000887                     0.000958                      0.0017330
# 26229 0.000931                     0.000934                      0.0009785
# 26230 0.000942                     0.000966                      0.0010180
# 26231 0.000930                     0.000974                      0.0009650
# 26232 0.001140                     0.001186                      0.0010435
# 26233 0.000954                     0.000959                      0.0009670
# 26234 0.000894                     0.000961                      0.0009540
# 26235 0.000889                     0.000911                      0.0010970
# 26236 0.000972                     0.001010                      0.0010805
# 26237 0.001023                     0.001022                      0.0014235
# 26238 0.000833                     0.000911                      0.0010455
# 26239 0.000921                     0.000926                      0.0009530
# 26240 0.000919                     0.000939                      0.0010230
# 26241 0.000815                     0.000919                             NA
# 26242 0.000897                     0.000937                      0.0012125
#       putamen   nacc      hippocampus pallidum   full_hypo
# 1     0.0009485 0.0010100 0.0011570   0.00100075 0.001763148
# 2     0.0009420 0.0009265 0.0010765   0.00096175 0.001639111
# 3     0.0008860 0.0008585 0.0010455   0.00088775 0.001557852
# 4     0.0010095 0.0009430 0.0011105   0.00114625 0.001716481
# 5     0.0008670 0.0008840 0.0011300   0.00083650 0.001585148
# 6     0.0008640 0.0008940 0.0010830   0.00085800 0.001528704
# 7     0.0008815 0.0009405 0.0011855   0.00084250 0.002008704
# 8     0.0010635 0.0009045 0.0011600   0.00092025 0.001807519
# 9     0.0010490 0.0009265 0.0010580   0.00096675 0.001801185
# 10    0.0009155 0.0008795 0.0011385   0.00088325 0.001814481
# 11    0.0009185 0.0011440 0.0010915   0.00085650 0.001533074
# 12    0.0008775 0.0009100 0.0010275   0.00113925 0.001431926
# 13    0.0008980 0.0008950 0.0010320   0.00088650 0.001509481
# 14    0.0010115 0.0009255 0.0010850   0.00096525 0.001557296
# 15    0.0012050 0.0015300 0.0012495   0.00144450 0.001805222
# 16    0.0014290 0.0013530 0.0010480   0.00132750 0.001670630
# 17    0.0009435 0.0009410 0.0011800   0.00092875 0.001482037
# 18    0.0008760 0.0009005 0.0011355   0.00088225 0.001600370
# 19    0.0008850 0.0008790 0.0010760   0.00104950 0.001672741
# 20    0.0008945 0.0009090 0.0010160   0.00094700 0.001507630
# 21    0.0009050 0.0009065 0.0010590   0.00089275 0.001509222
# 22    0.0008590 0.0009250 0.0009970   0.00089625 0.001419815
# 23    0.0008855 0.0009085 0.0010525   0.00113900 0.001651926
# 24    0.0008940 0.0012000 0.0011335   0.00085625 0.001808852
# 25    0.0009470 0.0009645 0.0010810   0.00097000 0.001630741
# 26    0.0009130 0.0009190 0.0010950   0.00097950 0.001701148
# 27    0.0009155 0.0009160 0.0010630   0.00097150 0.001444630
# 28    0.0008935 0.0009050 0.0011715   0.00099725 0.001764963
# 29    0.0009565 0.0009180 0.0013320   0.00088850 0.001741815
# 30    0.0009000 0.0008805 0.0010490   0.00092200 0.001434185
# ⋮     ⋮         ⋮         ⋮           ⋮          ⋮
# 26213 0.0008775 0.0008665 0.0014880   0.00096300 0.001747815
# 26214 0.0008965 0.0009025 0.0010735   0.00112000 0.001522370
# 26215 0.0008690 0.0008935 0.0010400   0.00096750 0.001527630
# 26216 0.0009285 0.0010000 0.0010820   0.00095050 0.001706630
# 26217 0.0009005 0.0009340 0.0010355   0.00107975 0.001420556
# 26218 0.0008820 0.0008975 0.0010215   0.00088450 0.001489370
# 26219 0.0008725 0.0008645 0.0012425   0.00081650 0.001860519
# 26220 0.0009420 0.0009765 0.0011025   0.00089450 0.001795889
# 26221 0.0009080 0.0009105 0.0011025   0.00089250 0.001725889
# 26222 0.0009075 0.0009155 0.0012915   0.00093750 0.001863148
# 26223 0.0009100 0.0009000 0.0010970   0.00094175 0.001653741
# 26224 0.0009250 0.0009375 0.0011045   0.00090450 0.001785333
# 26225 0.0008710 0.0008490 0.0011040   0.00094300 0.001603667
# 26226 0.0009320 0.0009765 0.0011425   0.00091100 0.001826407
# 26227 0.0008910 0.0008905 0.0010940   0.00091400 0.001568333
# 26228 0.0009075 0.0008985 0.0013975   0.00092300 0.001731963
# 26229 0.0008400 0.0008975 0.0010130   0.00089875 0.001649037
# 26230 0.0009030 0.0009265 0.0010145   0.00092225 0.001700741
# 26231 0.0009055 0.0008995 0.0010830   0.00093250 0.001431778
# 26232 0.0008670 0.0009285 0.0011325   0.00108950 0.001497407
# 26233 0.0009245 0.0008745 0.0010450   0.00096275 0.001574333
# 26234 0.0008885 0.0008605 0.0010970   0.00091975 0.001504185
# 26235 0.0008675 0.0008995 0.0012185   0.00087825 0.001440815
# 26236 0.0009695 0.0009510 0.0011380   0.00099125 0.001576778
# 26237 0.0009520 0.0008770 0.0011885   0.00099450 0.001830000
# 26238 0.0008895 0.0008755 0.0010470   0.00085425 0.001610407
# 26239 0.0008955 0.0009245 0.0011560   0.00092250 0.001512407
# 26240 0.0009045 0.0009115 0.0010725   0.00092650 0.001508667
# 26241 0.0009500 0.0010750 0.0010805   0.00089475 0.001601481
# 26242 0.0009230 0.0009220 0.0010765   0.00091075 0.001653111

# %%
# Define necessary variables
subject_data <- list(ad_subj_data, fa_subj_data, md_subj_data, rd_subj_data)
subject_datasets <- c("ad", "fa", "md", "rd")
brain_regions <- c("caudate", "putamen", "nacc", "hippocampus", "pallidum", "full_hypo")
vars <- c("CRP", "Glucose", "HBA1C", "Cholesterol", "HDL_Chol", "LDL_Chol", "Triglycerides", "Systolic_BP", "Diastolic_BP")
variables <- c("c.reactive_protein_30710.0.0", 
                        "glucose_30740.0.0", "glycated_haemoglobin_hba1c_30750.0.0", 
                        "cholesterol_30690.0.0", "hdl_cholesterol_30760.0.0", 
                        "ldl_direct_30780.0.0", "triglycerides_30870.0.0", 
                        "systolic_blood_pressure_automated_reading_4080.0.1", 
                        "diastolic_blood_pressure_automated_reading_4079.0.1")
all_data_summary <- data.frame()

# %%
# Loop through the DTI measure data frames
for (i in seq_along(subject_data)) {
    current_data <- subject_data[[i]]
    j=1
    # Loop through each brain region
    for (region in brain_regions) {
        k=1
        # Loop through each obesity-related parameter
        for (variable in variables) {
            # Calculate regression for current region, parameter, and data frame
            lm_model <- lm(get(region) ~ get(variable) + 
                           age_when_attended_assessment_centre_21003.2.0 + body_mass_index_bmi_21001.2.0 +
                           poly(age_when_attended_assessment_centre_21003.2.0, 2, raw=TRUE) * sex_31.0.0 +
                           poly(difftime(as.Date(date_of_attending_assessment_centre_53.2.0),
                                min(as.Date(date_of_attending_assessment_centre_53.2.0)), units='days'), 2, raw=TRUE) + 
                           uk_biobank_assessment_centre_54.2.0 + 
                           volume_of_estimatedtotalintracranial_whole_brain_26521.2.0, data = current_data)
            summary_model <- summary(lm_model)
            values <- data.frame(summary_model$coefficients[2,])
            values <- as.data.frame(t(values))
            # Create necessary columns to make the data frame more readable
            values$metric <- subject_datasets[i]
            values$region <- region
            values$measure <- vars[k]
            # Rename row names to relevant patient information
            row_name <- paste(subject_datasets[i],"_", region, "_", variable)
            rownames(values) <- row_name 
            all_data_summary <- rbind(all_data_summary, values)
            k=k+1
        j=j+1
        }
    }
}

# %%
# Write CSV file for summarized UKBB data
write.csv(all_data_summary, "~/linear_regression/UKBB_all_data_summary_bmi_covariate.csv")

# %%
all_data_summary
# Out:
#                                                                        Estimate
# ad _ caudate _ c.reactive_protein_30710.0.0                             4.244933e-06
# ad _ caudate _ glucose_30740.0.0                                        3.762371e-06
# ad _ caudate _ glycated_haemoglobin_hba1c_30750.0.0                     6.405129e-07
# ad _ caudate _ cholesterol_30690.0.0                                    3.143001e-06
# ad _ caudate _ hdl_cholesterol_30760.0.0                                7.961500e-06
# ad _ caudate _ ldl_direct_30780.0.0                                     2.706446e-06
# ad _ caudate _ triglycerides_30870.0.0                                  4.920195e-06
# ad _ caudate _ systolic_blood_pressure_automated_reading_4080.0.1       3.386402e-07
# ad _ caudate _ diastolic_blood_pressure_automated_reading_4079.0.1      6.583806e-07
# ad _ putamen _ c.reactive_protein_30710.0.0                            -1.776700e-05
# ad _ putamen _ glucose_30740.0.0                                        2.569995e-05
# ad _ putamen _ glycated_haemoglobin_hba1c_30750.0.0                    -1.204038e-06
# ad _ putamen _ cholesterol_30690.0.0                                    5.718851e-05
# ad _ putamen _ hdl_cholesterol_30760.0.0                                1.551643e-05
# ad _ putamen _ ldl_direct_30780.0.0                                     6.651230e-05
# ad _ putamen _ triglycerides_30870.0.0                                  5.421839e-05
# ad _ putamen _ systolic_blood_pressure_automated_reading_4080.0.1       1.844754e-07
# ad _ putamen _ diastolic_blood_pressure_automated_reading_4079.0.1      8.940662e-07
# ad _ nacc _ c.reactive_protein_30710.0.0                               -1.887028e-05
# ad _ nacc _ glucose_30740.0.0                                           2.563175e-05
# ad _ nacc _ glycated_haemoglobin_hba1c_30750.0.0                       -9.768613e-07
# ad _ nacc _ cholesterol_30690.0.0                                       5.972955e-05
# ad _ nacc _ hdl_cholesterol_30760.0.0                                   1.248869e-05
# ad _ nacc _ ldl_direct_30780.0.0                                        6.960066e-05
# ad _ nacc _ triglycerides_30870.0.0                                     5.639379e-05
# ad _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1         -1.500911e-07
# ad _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1         3.623146e-07
# ad _ hippocampus _ c.reactive_protein_30710.0.0                        -1.876759e-05
# ad _ hippocampus _ glucose_30740.0.0                                    2.809919e-05
# ad _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                -1.029883e-06
# ⋮                                                                      ⋮
# rd _ nacc _ triglycerides_30870.0.0                                     9.058950e-07
# rd _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1          2.098392e-08
# rd _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1        -4.026789e-08
# rd _ hippocampus _ c.reactive_protein_30710.0.0                         9.171579e-07
# rd _ hippocampus _ glucose_30740.0.0                                    2.575103e-06
# rd _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                 1.538497e-07
# rd _ hippocampus _ cholesterol_30690.0.0                                6.970909e-07
# rd _ hippocampus _ hdl_cholesterol_30760.0.0                            4.188440e-06
# rd _ hippocampus _ ldl_direct_30780.0.0                                 1.517811e-07
# rd _ hippocampus _ triglycerides_30870.0.0                             -2.495801e-07
# rd _ hippocampus _ systolic_blood_pressure_automated_reading_4080.0.1   2.028891e-07
# rd _ hippocampus _ diastolic_blood_pressure_automated_reading_4079.0.1  3.996602e-07
# rd _ pallidum _ c.reactive_protein_30710.0.0                           -1.686106e-06
# rd _ pallidum _ glucose_30740.0.0                                       9.246539e-07
# rd _ pallidum _ glycated_haemoglobin_hba1c_30750.0.0                    1.218969e-07
# rd _ pallidum _ cholesterol_30690.0.0                                   1.005309e-06
# rd _ pallidum _ hdl_cholesterol_30760.0.0                              -3.169936e-07
# rd _ pallidum _ ldl_direct_30780.0.0                                    1.668176e-06
# rd _ pallidum _ triglycerides_30870.0.0                                 8.885421e-07
# rd _ pallidum _ systolic_blood_pressure_automated_reading_4080.0.1      1.549777e-07
# rd _ pallidum _ diastolic_blood_pressure_automated_reading_4079.0.1     2.725649e-07
# rd _ full_hypo _ c.reactive_protein_30710.0.0                           1.177289e-06
# rd _ full_hypo _ glucose_30740.0.0                                      2.460169e-06
# rd _ full_hypo _ glycated_haemoglobin_hba1c_30750.0.0                   6.820861e-07
# rd _ full_hypo _ cholesterol_30690.0.0                                  5.344514e-07
# rd _ full_hypo _ hdl_cholesterol_30760.0.0                              1.402227e-05
# rd _ full_hypo _ ldl_direct_30780.0.0                                  -1.134803e-06
# rd _ full_hypo _ triglycerides_30870.0.0                                2.497930e-07
# rd _ full_hypo _ systolic_blood_pressure_automated_reading_4080.0.1     3.173366e-08
# rd _ full_hypo _ diastolic_blood_pressure_automated_reading_4079.0.1    3.153575e-07
#                                                                        Std. Error
# ad _ caudate _ c.reactive_protein_30710.0.0                            9.488018e-07
# ad _ caudate _ glucose_30740.0.0                                       1.945969e-06
# ad _ caudate _ glycated_haemoglobin_hba1c_30750.0.0                    2.902144e-07
# ad _ caudate _ cholesterol_30690.0.0                                   9.586258e-07
# ad _ caudate _ hdl_cholesterol_30760.0.0                               3.277328e-06
# ad _ caudate _ ldl_direct_30780.0.0                                    1.242041e-06
# ad _ caudate _ triglycerides_30870.0.0                                 1.410702e-06
# ad _ caudate _ systolic_blood_pressure_automated_reading_4080.0.1      6.225101e-08
# ad _ caudate _ diastolic_blood_pressure_automated_reading_4079.0.1     1.053131e-07
# ad _ putamen _ c.reactive_protein_30710.0.0                            2.193484e-05
# ad _ putamen _ glucose_30740.0.0                                       4.625031e-05
# ad _ putamen _ glycated_haemoglobin_hba1c_30750.0.0                    6.587186e-06
# ad _ putamen _ cholesterol_30690.0.0                                   2.131608e-05
# ad _ putamen _ hdl_cholesterol_30760.0.0                               7.665654e-05
# ad _ putamen _ ldl_direct_30780.0.0                                    2.762060e-05
# ad _ putamen _ triglycerides_30870.0.0                                 3.187242e-05
# ad _ putamen _ systolic_blood_pressure_automated_reading_4080.0.1      1.399433e-06
# ad _ putamen _ diastolic_blood_pressure_automated_reading_4079.0.1     2.374411e-06
# ad _ nacc _ c.reactive_protein_30710.0.0                               2.288494e-05
# ad _ nacc _ glucose_30740.0.0                                          4.825249e-05
# ad _ nacc _ glycated_haemoglobin_hba1c_30750.0.0                       6.872724e-06
# ad _ nacc _ cholesterol_30690.0.0                                      2.224043e-05
# ad _ nacc _ hdl_cholesterol_30760.0.0                                  7.997685e-05
# ad _ nacc _ ldl_direct_30780.0.0                                       2.881831e-05
# ad _ nacc _ triglycerides_30870.0.0                                    3.325380e-05
# ad _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1         1.460063e-06
# ad _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1        2.477288e-06
# ad _ hippocampus _ c.reactive_protein_30710.0.0                        2.363195e-05
# ad _ hippocampus _ glucose_30740.0.0                                   4.983402e-05
# ad _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                7.097773e-06
# ⋮                                                                      ⋮
# rd _ nacc _ triglycerides_30870.0.0                                    1.271874e-06
# rd _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1         5.502276e-08
# rd _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1        9.346807e-08
# rd _ hippocampus _ c.reactive_protein_30710.0.0                        7.460380e-07
# rd _ hippocampus _ glucose_30740.0.0                                   1.545103e-06
# rd _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                2.306477e-07
# rd _ hippocampus _ cholesterol_30690.0.0                               7.563429e-07
# rd _ hippocampus _ hdl_cholesterol_30760.0.0                           2.605073e-06
# rd _ hippocampus _ ldl_direct_30780.0.0                                9.790736e-07
# rd _ hippocampus _ triglycerides_30870.0.0                             1.121616e-06
# rd _ hippocampus _ systolic_blood_pressure_automated_reading_4080.0.1  4.952872e-08
# rd _ hippocampus _ diastolic_blood_pressure_automated_reading_4079.0.1 8.419738e-08
# rd _ pallidum _ c.reactive_protein_30710.0.0                           6.885364e-07
# rd _ pallidum _ glucose_30740.0.0                                      1.406714e-06
# rd _ pallidum _ glycated_haemoglobin_hba1c_30750.0.0                   2.102182e-07
# rd _ pallidum _ cholesterol_30690.0.0                                  6.905603e-07
# rd _ pallidum _ hdl_cholesterol_30760.0.0                              2.370328e-06
# rd _ pallidum _ ldl_direct_30780.0.0                                   8.941631e-07
# rd _ pallidum _ triglycerides_30870.0.0                                1.022815e-06
# rd _ pallidum _ systolic_blood_pressure_automated_reading_4080.0.1     4.487696e-08
# rd _ pallidum _ diastolic_blood_pressure_automated_reading_4079.0.1    7.623600e-08
# rd _ full_hypo _ c.reactive_protein_30710.0.0                          7.322455e-07
# rd _ full_hypo _ glucose_30740.0.0                                     1.496584e-06
# rd _ full_hypo _ glycated_haemoglobin_hba1c_30750.0.0                  2.236923e-07
# rd _ full_hypo _ cholesterol_30690.0.0                                 7.361084e-07
# rd _ full_hypo _ hdl_cholesterol_30760.0.0                             2.516254e-06
# rd _ full_hypo _ ldl_direct_30780.0.0                                  9.534307e-07
# rd _ full_hypo _ triglycerides_30870.0.0                               1.089086e-06
# rd _ full_hypo _ systolic_blood_pressure_automated_reading_4080.0.1    4.749577e-08
# rd _ full_hypo _ diastolic_blood_pressure_automated_reading_4079.0.1   8.068098e-08
#                                                                        t value
# ad _ caudate _ c.reactive_protein_30710.0.0                             4.4739933
# ad _ caudate _ glucose_30740.0.0                                        1.9334174
# ad _ caudate _ glycated_haemoglobin_hba1c_30750.0.0                     2.2070336
# ad _ caudate _ cholesterol_30690.0.0                                    3.2786522
# ad _ caudate _ hdl_cholesterol_30760.0.0                                2.4292657
# ad _ caudate _ ldl_direct_30780.0.0                                     2.1790303
# ad _ caudate _ triglycerides_30870.0.0                                  3.4877649
# ad _ caudate _ systolic_blood_pressure_automated_reading_4080.0.1       5.4399157
# ad _ caudate _ diastolic_blood_pressure_automated_reading_4079.0.1      6.2516518
# ad _ putamen _ c.reactive_protein_30710.0.0                            -0.8099898
# ad _ putamen _ glucose_30740.0.0                                        0.5556709
# ad _ putamen _ glycated_haemoglobin_hba1c_30750.0.0                    -0.1827848
# ad _ putamen _ cholesterol_30690.0.0                                    2.6828807
# ad _ putamen _ hdl_cholesterol_30760.0.0                                0.2024149
# ad _ putamen _ ldl_direct_30780.0.0                                     2.4080684
# ad _ putamen _ triglycerides_30870.0.0                                  1.7011067
# ad _ putamen _ systolic_blood_pressure_automated_reading_4080.0.1       0.1318215
# ad _ putamen _ diastolic_blood_pressure_automated_reading_4079.0.1      0.3765423
# ad _ nacc _ c.reactive_protein_30710.0.0                               -0.8245719
# ad _ nacc _ glucose_30740.0.0                                           0.5312006
# ad _ nacc _ glycated_haemoglobin_hba1c_30750.0.0                       -0.1421360
# ad _ nacc _ cholesterol_30690.0.0                                       2.6856295
# ad _ nacc _ hdl_cholesterol_30760.0.0                                   0.1561538
# ad _ nacc _ ldl_direct_30780.0.0                                        2.4151538
# ad _ nacc _ triglycerides_30870.0.0                                     1.6958600
# ad _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1         -0.1027977
# ad _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1         0.1462545
# ad _ hippocampus _ c.reactive_protein_30710.0.0                        -0.7941620
# ad _ hippocampus _ glucose_30740.0.0                                    0.5638554
# ad _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                -0.1450995
# ⋮                                                                      ⋮
# rd _ nacc _ triglycerides_30870.0.0                                     0.7122524
# rd _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1          0.3813680
# rd _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1        -0.4308197
# rd _ hippocampus _ c.reactive_protein_30710.0.0                         1.2293715
# rd _ hippocampus _ glucose_30740.0.0                                    1.6666221
# rd _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                 0.6670332
# rd _ hippocampus _ cholesterol_30690.0.0                                0.9216598
# rd _ hippocampus _ hdl_cholesterol_30760.0.0                            1.6078011
# rd _ hippocampus _ ldl_direct_30780.0.0                                 0.1550252
# rd _ hippocampus _ triglycerides_30870.0.0                             -0.2225183
# rd _ hippocampus _ systolic_blood_pressure_automated_reading_4080.0.1   4.0963932
# rd _ hippocampus _ diastolic_blood_pressure_automated_reading_4079.0.1  4.7467060
# rd _ pallidum _ c.reactive_protein_30710.0.0                           -2.4488262
# rd _ pallidum _ glucose_30740.0.0                                       0.6573148
# rd _ pallidum _ glycated_haemoglobin_hba1c_30750.0.0                    0.5798591
# rd _ pallidum _ cholesterol_30690.0.0                                   1.4557879
# rd _ pallidum _ hdl_cholesterol_30760.0.0                              -0.1337341
# rd _ pallidum _ ldl_direct_30780.0.0                                    1.8656285
# rd _ pallidum _ triglycerides_30870.0.0                                 0.8687218
# rd _ pallidum _ systolic_blood_pressure_automated_reading_4080.0.1      3.4533900
# rd _ pallidum _ diastolic_blood_pressure_automated_reading_4079.0.1     3.5752779
# rd _ full_hypo _ c.reactive_protein_30710.0.0                           1.6077789
# rd _ full_hypo _ glucose_30740.0.0                                      1.6438559
# rd _ full_hypo _ glycated_haemoglobin_hba1c_30750.0.0                   3.0492152
# rd _ full_hypo _ cholesterol_30690.0.0                                  0.7260499
# rd _ full_hypo _ hdl_cholesterol_30760.0.0                              5.5726765
# rd _ full_hypo _ ldl_direct_30780.0.0                                  -1.1902311
# rd _ full_hypo _ triglycerides_30870.0.0                                0.2293602
# rd _ full_hypo _ systolic_blood_pressure_automated_reading_4080.0.1     0.6681366
# rd _ full_hypo _ diastolic_blood_pressure_automated_reading_4079.0.1    3.9086975
#                                                                        Pr(>|t|)
# ad _ caudate _ c.reactive_protein_30710.0.0                            7.720244e-06
# ad _ caudate _ glucose_30740.0.0                                       5.320000e-02
# ad _ caudate _ glycated_haemoglobin_hba1c_30750.0.0                    2.732277e-02
# ad _ caudate _ cholesterol_30690.0.0                                   1.044744e-03
# ad _ caudate _ hdl_cholesterol_30760.0.0                               1.513864e-02
# ad _ caudate _ ldl_direct_30780.0.0                                    2.934057e-02
# ad _ caudate _ triglycerides_30870.0.0                                 4.880981e-04
# ad _ caudate _ systolic_blood_pressure_automated_reading_4080.0.1      5.391552e-08
# ad _ caudate _ diastolic_blood_pressure_automated_reading_4079.0.1     4.141315e-10
# ad _ putamen _ c.reactive_protein_30710.0.0                            4.179548e-01
# ad _ putamen _ glucose_30740.0.0                                       5.784418e-01
# ad _ putamen _ glycated_haemoglobin_hba1c_30750.0.0                    8.549685e-01
# ad _ putamen _ cholesterol_30690.0.0                                   7.304215e-03
# ad _ putamen _ hdl_cholesterol_30760.0.0                               8.395943e-01
# ad _ putamen _ ldl_direct_30780.0.0                                    1.604485e-02
# ad _ putamen _ triglycerides_30870.0.0                                 8.893648e-02
# ad _ putamen _ systolic_blood_pressure_automated_reading_4080.0.1      8.951267e-01
# ad _ putamen _ diastolic_blood_pressure_automated_reading_4079.0.1     7.065172e-01
# ad _ nacc _ c.reactive_protein_30710.0.0                               4.096236e-01
# ad _ nacc _ glucose_30740.0.0                                          5.952854e-01
# ad _ nacc _ glycated_haemoglobin_hba1c_30750.0.0                       8.869739e-01
# ad _ nacc _ cholesterol_30690.0.0                                      7.244421e-03
# ad _ nacc _ hdl_cholesterol_30760.0.0                                  8.759133e-01
# ad _ nacc _ ldl_direct_30780.0.0                                       1.573617e-02
# ad _ nacc _ triglycerides_30870.0.0                                    8.992592e-02
# ad _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1         9.181244e-01
# ad _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1        8.837218e-01
# ad _ hippocampus _ c.reactive_protein_30710.0.0                        4.271097e-01
# ad _ hippocampus _ glucose_30740.0.0                                   5.728586e-01
# ad _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                8.846336e-01
# ⋮                                                                      ⋮
# rd _ nacc _ triglycerides_30870.0.0                                    4.763157e-01
# rd _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1         7.029337e-01
# rd _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1        6.666035e-01
# rd _ hippocampus _ c.reactive_protein_30710.0.0                        2.189457e-01
# rd _ hippocampus _ glucose_30740.0.0                                   9.560462e-02
# rd _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                5.047576e-01
# rd _ hippocampus _ cholesterol_30690.0.0                               3.567155e-01
# rd _ hippocampus _ hdl_cholesterol_30760.0.0                           1.078935e-01
# rd _ hippocampus _ ldl_direct_30780.0.0                                8.768028e-01
# rd _ hippocampus _ triglycerides_30870.0.0                             8.239124e-01
# rd _ hippocampus _ systolic_blood_pressure_automated_reading_4080.0.1  4.210719e-05
# rd _ hippocampus _ diastolic_blood_pressure_automated_reading_4079.0.1 2.079961e-06
# rd _ pallidum _ c.reactive_protein_30710.0.0                           1.433998e-02
# rd _ pallidum _ glucose_30740.0.0                                      5.109858e-01
# rd _ pallidum _ glycated_haemoglobin_hba1c_30750.0.0                   5.620153e-01
# rd _ pallidum _ cholesterol_30690.0.0                                  1.454646e-01
# rd _ pallidum _ hdl_cholesterol_30760.0.0                              8.936141e-01
# rd _ pallidum _ ldl_direct_30780.0.0                                   6.210584e-02
# rd _ pallidum _ triglycerides_30870.0.0                                3.850084e-01
# rd _ pallidum _ systolic_blood_pressure_automated_reading_4080.0.1     5.545835e-04
# rd _ pallidum _ diastolic_blood_pressure_automated_reading_4079.0.1    3.505708e-04
# rd _ full_hypo _ c.reactive_protein_30710.0.0                          1.078983e-01
# rd _ full_hypo _ glucose_30740.0.0                                     1.002215e-01
# rd _ full_hypo _ glycated_haemoglobin_hba1c_30750.0.0                  2.297084e-03
# rd _ full_hypo _ cholesterol_30690.0.0                                 4.678156e-01
# rd _ full_hypo _ hdl_cholesterol_30760.0.0                             2.539605e-08
# rd _ full_hypo _ ldl_direct_30780.0.0                                  2.339680e-01
# rd _ full_hypo _ triglycerides_30870.0.0                               8.185911e-01
# rd _ full_hypo _ systolic_blood_pressure_automated_reading_4080.0.1    5.040533e-01
# rd _ full_hypo _ diastolic_blood_pressure_automated_reading_4079.0.1   9.306726e-05
#                                                                        metric
# ad _ caudate _ c.reactive_protein_30710.0.0                            ad
# ad _ caudate _ glucose_30740.0.0                                       ad
# ad _ caudate _ glycated_haemoglobin_hba1c_30750.0.0                    ad
# ad _ caudate _ cholesterol_30690.0.0                                   ad
# ad _ caudate _ hdl_cholesterol_30760.0.0                               ad
# ad _ caudate _ ldl_direct_30780.0.0                                    ad
# ad _ caudate _ triglycerides_30870.0.0                                 ad
# ad _ caudate _ systolic_blood_pressure_automated_reading_4080.0.1      ad
# ad _ caudate _ diastolic_blood_pressure_automated_reading_4079.0.1     ad
# ad _ putamen _ c.reactive_protein_30710.0.0                            ad
# ad _ putamen _ glucose_30740.0.0                                       ad
# ad _ putamen _ glycated_haemoglobin_hba1c_30750.0.0                    ad
# ad _ putamen _ cholesterol_30690.0.0                                   ad
# ad _ putamen _ hdl_cholesterol_30760.0.0                               ad
# ad _ putamen _ ldl_direct_30780.0.0                                    ad
# ad _ putamen _ triglycerides_30870.0.0                                 ad
# ad _ putamen _ systolic_blood_pressure_automated_reading_4080.0.1      ad
# ad _ putamen _ diastolic_blood_pressure_automated_reading_4079.0.1     ad
# ad _ nacc _ c.reactive_protein_30710.0.0                               ad
# ad _ nacc _ glucose_30740.0.0                                          ad
# ad _ nacc _ glycated_haemoglobin_hba1c_30750.0.0                       ad
# ad _ nacc _ cholesterol_30690.0.0                                      ad
# ad _ nacc _ hdl_cholesterol_30760.0.0                                  ad
# ad _ nacc _ ldl_direct_30780.0.0                                       ad
# ad _ nacc _ triglycerides_30870.0.0                                    ad
# ad _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1         ad
# ad _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1        ad
# ad _ hippocampus _ c.reactive_protein_30710.0.0                        ad
# ad _ hippocampus _ glucose_30740.0.0                                   ad
# ad _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                ad
# ⋮                                                                      ⋮
# rd _ nacc _ triglycerides_30870.0.0                                    rd
# rd _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1         rd
# rd _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1        rd
# rd _ hippocampus _ c.reactive_protein_30710.0.0                        rd
# rd _ hippocampus _ glucose_30740.0.0                                   rd
# rd _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                rd
# rd _ hippocampus _ cholesterol_30690.0.0                               rd
# rd _ hippocampus _ hdl_cholesterol_30760.0.0                           rd
# rd _ hippocampus _ ldl_direct_30780.0.0                                rd
# rd _ hippocampus _ triglycerides_30870.0.0                             rd
# rd _ hippocampus _ systolic_blood_pressure_automated_reading_4080.0.1  rd
# rd _ hippocampus _ diastolic_blood_pressure_automated_reading_4079.0.1 rd
# rd _ pallidum _ c.reactive_protein_30710.0.0                           rd
# rd _ pallidum _ glucose_30740.0.0                                      rd
# rd _ pallidum _ glycated_haemoglobin_hba1c_30750.0.0                   rd
# rd _ pallidum _ cholesterol_30690.0.0                                  rd
# rd _ pallidum _ hdl_cholesterol_30760.0.0                              rd
# rd _ pallidum _ ldl_direct_30780.0.0                                   rd
# rd _ pallidum _ triglycerides_30870.0.0                                rd
# rd _ pallidum _ systolic_blood_pressure_automated_reading_4080.0.1     rd
# rd _ pallidum _ diastolic_blood_pressure_automated_reading_4079.0.1    rd
# rd _ full_hypo _ c.reactive_protein_30710.0.0                          rd
# rd _ full_hypo _ glucose_30740.0.0                                     rd
# rd _ full_hypo _ glycated_haemoglobin_hba1c_30750.0.0                  rd
# rd _ full_hypo _ cholesterol_30690.0.0                                 rd
# rd _ full_hypo _ hdl_cholesterol_30760.0.0                             rd
# rd _ full_hypo _ ldl_direct_30780.0.0                                  rd
# rd _ full_hypo _ triglycerides_30870.0.0                               rd
# rd _ full_hypo _ systolic_blood_pressure_automated_reading_4080.0.1    rd
# rd _ full_hypo _ diastolic_blood_pressure_automated_reading_4079.0.1   rd
#                                                                        region
# ad _ caudate _ c.reactive_protein_30710.0.0                            caudate
# ad _ caudate _ glucose_30740.0.0                                       caudate
# ad _ caudate _ glycated_haemoglobin_hba1c_30750.0.0                    caudate
# ad _ caudate _ cholesterol_30690.0.0                                   caudate
# ad _ caudate _ hdl_cholesterol_30760.0.0                               caudate
# ad _ caudate _ ldl_direct_30780.0.0                                    caudate
# ad _ caudate _ triglycerides_30870.0.0                                 caudate
# ad _ caudate _ systolic_blood_pressure_automated_reading_4080.0.1      caudate
# ad _ caudate _ diastolic_blood_pressure_automated_reading_4079.0.1     caudate
# ad _ putamen _ c.reactive_protein_30710.0.0                            putamen
# ad _ putamen _ glucose_30740.0.0                                       putamen
# ad _ putamen _ glycated_haemoglobin_hba1c_30750.0.0                    putamen
# ad _ putamen _ cholesterol_30690.0.0                                   putamen
# ad _ putamen _ hdl_cholesterol_30760.0.0                               putamen
# ad _ putamen _ ldl_direct_30780.0.0                                    putamen
# ad _ putamen _ triglycerides_30870.0.0                                 putamen
# ad _ putamen _ systolic_blood_pressure_automated_reading_4080.0.1      putamen
# ad _ putamen _ diastolic_blood_pressure_automated_reading_4079.0.1     putamen
# ad _ nacc _ c.reactive_protein_30710.0.0                               nacc
# ad _ nacc _ glucose_30740.0.0                                          nacc
# ad _ nacc _ glycated_haemoglobin_hba1c_30750.0.0                       nacc
# ad _ nacc _ cholesterol_30690.0.0                                      nacc
# ad _ nacc _ hdl_cholesterol_30760.0.0                                  nacc
# ad _ nacc _ ldl_direct_30780.0.0                                       nacc
# ad _ nacc _ triglycerides_30870.0.0                                    nacc
# ad _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1         nacc
# ad _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1        nacc
# ad _ hippocampus _ c.reactive_protein_30710.0.0                        hippocampus
# ad _ hippocampus _ glucose_30740.0.0                                   hippocampus
# ad _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                hippocampus
# ⋮                                                                      ⋮
# rd _ nacc _ triglycerides_30870.0.0                                    nacc
# rd _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1         nacc
# rd _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1        nacc
# rd _ hippocampus _ c.reactive_protein_30710.0.0                        hippocampus
# rd _ hippocampus _ glucose_30740.0.0                                   hippocampus
# rd _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                hippocampus
# rd _ hippocampus _ cholesterol_30690.0.0                               hippocampus
# rd _ hippocampus _ hdl_cholesterol_30760.0.0                           hippocampus
# rd _ hippocampus _ ldl_direct_30780.0.0                                hippocampus
# rd _ hippocampus _ triglycerides_30870.0.0                             hippocampus
# rd _ hippocampus _ systolic_blood_pressure_automated_reading_4080.0.1  hippocampus
# rd _ hippocampus _ diastolic_blood_pressure_automated_reading_4079.0.1 hippocampus
# rd _ pallidum _ c.reactive_protein_30710.0.0                           pallidum
# rd _ pallidum _ glucose_30740.0.0                                      pallidum
# rd _ pallidum _ glycated_haemoglobin_hba1c_30750.0.0                   pallidum
# rd _ pallidum _ cholesterol_30690.0.0                                  pallidum
# rd _ pallidum _ hdl_cholesterol_30760.0.0                              pallidum
# rd _ pallidum _ ldl_direct_30780.0.0                                   pallidum
# rd _ pallidum _ triglycerides_30870.0.0                                pallidum
# rd _ pallidum _ systolic_blood_pressure_automated_reading_4080.0.1     pallidum
# rd _ pallidum _ diastolic_blood_pressure_automated_reading_4079.0.1    pallidum
# rd _ full_hypo _ c.reactive_protein_30710.0.0                          full_hypo
# rd _ full_hypo _ glucose_30740.0.0                                     full_hypo
# rd _ full_hypo _ glycated_haemoglobin_hba1c_30750.0.0                  full_hypo
# rd _ full_hypo _ cholesterol_30690.0.0                                 full_hypo
# rd _ full_hypo _ hdl_cholesterol_30760.0.0                             full_hypo
# rd _ full_hypo _ ldl_direct_30780.0.0                                  full_hypo
# rd _ full_hypo _ triglycerides_30870.0.0                               full_hypo
# rd _ full_hypo _ systolic_blood_pressure_automated_reading_4080.0.1    full_hypo
# rd _ full_hypo _ diastolic_blood_pressure_automated_reading_4079.0.1   full_hypo
#                                                                        measure
# ad _ caudate _ c.reactive_protein_30710.0.0                            CRP
# ad _ caudate _ glucose_30740.0.0                                       Glucose
# ad _ caudate _ glycated_haemoglobin_hba1c_30750.0.0                    HBA1C
# ad _ caudate _ cholesterol_30690.0.0                                   Cholesterol
# ad _ caudate _ hdl_cholesterol_30760.0.0                               HDL_Chol
# ad _ caudate _ ldl_direct_30780.0.0                                    LDL_Chol
# ad _ caudate _ triglycerides_30870.0.0                                 Triglycerides
# ad _ caudate _ systolic_blood_pressure_automated_reading_4080.0.1      Systolic_BP
# ad _ caudate _ diastolic_blood_pressure_automated_reading_4079.0.1     Diastolic_BP
# ad _ putamen _ c.reactive_protein_30710.0.0                            CRP
# ad _ putamen _ glucose_30740.0.0                                       Glucose
# ad _ putamen _ glycated_haemoglobin_hba1c_30750.0.0                    HBA1C
# ad _ putamen _ cholesterol_30690.0.0                                   Cholesterol
# ad _ putamen _ hdl_cholesterol_30760.0.0                               HDL_Chol
# ad _ putamen _ ldl_direct_30780.0.0                                    LDL_Chol
# ad _ putamen _ triglycerides_30870.0.0                                 Triglycerides
# ad _ putamen _ systolic_blood_pressure_automated_reading_4080.0.1      Systolic_BP
# ad _ putamen _ diastolic_blood_pressure_automated_reading_4079.0.1     Diastolic_BP
# ad _ nacc _ c.reactive_protein_30710.0.0                               CRP
# ad _ nacc _ glucose_30740.0.0                                          Glucose
# ad _ nacc _ glycated_haemoglobin_hba1c_30750.0.0                       HBA1C
# ad _ nacc _ cholesterol_30690.0.0                                      Cholesterol
# ad _ nacc _ hdl_cholesterol_30760.0.0                                  HDL_Chol
# ad _ nacc _ ldl_direct_30780.0.0                                       LDL_Chol
# ad _ nacc _ triglycerides_30870.0.0                                    Triglycerides
# ad _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1         Systolic_BP
# ad _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1        Diastolic_BP
# ad _ hippocampus _ c.reactive_protein_30710.0.0                        CRP
# ad _ hippocampus _ glucose_30740.0.0                                   Glucose
# ad _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                HBA1C
# ⋮                                                                      ⋮
# rd _ nacc _ triglycerides_30870.0.0                                    Triglycerides
# rd _ nacc _ systolic_blood_pressure_automated_reading_4080.0.1         Systolic_BP
# rd _ nacc _ diastolic_blood_pressure_automated_reading_4079.0.1        Diastolic_BP
# rd _ hippocampus _ c.reactive_protein_30710.0.0                        CRP
# rd _ hippocampus _ glucose_30740.0.0                                   Glucose
# rd _ hippocampus _ glycated_haemoglobin_hba1c_30750.0.0                HBA1C
# rd _ hippocampus _ cholesterol_30690.0.0                               Cholesterol
# rd _ hippocampus _ hdl_cholesterol_30760.0.0                           HDL_Chol
# rd _ hippocampus _ ldl_direct_30780.0.0                                LDL_Chol
# rd _ hippocampus _ triglycerides_30870.0.0                             Triglycerides
# rd _ hippocampus _ systolic_blood_pressure_automated_reading_4080.0.1  Systolic_BP
# rd _ hippocampus _ diastolic_blood_pressure_automated_reading_4079.0.1 Diastolic_BP
# rd _ pallidum _ c.reactive_protein_30710.0.0                           CRP
# rd _ pallidum _ glucose_30740.0.0                                      Glucose
# rd _ pallidum _ glycated_haemoglobin_hba1c_30750.0.0                   HBA1C
# rd _ pallidum _ cholesterol_30690.0.0                                  Cholesterol
# rd _ pallidum _ hdl_cholesterol_30760.0.0                              HDL_Chol
# rd _ pallidum _ ldl_direct_30780.0.0                                   LDL_Chol
# rd _ pallidum _ triglycerides_30870.0.0                                Triglycerides
# rd _ pallidum _ systolic_blood_pressure_automated_reading_4080.0.1     Systolic_BP
# rd _ pallidum _ diastolic_blood_pressure_automated_reading_4079.0.1    Diastolic_BP
# rd _ full_hypo _ c.reactive_protein_30710.0.0                          CRP
# rd _ full_hypo _ glucose_30740.0.0                                     Glucose
# rd _ full_hypo _ glycated_haemoglobin_hba1c_30750.0.0                  HBA1C
# rd _ full_hypo _ cholesterol_30690.0.0                                 Cholesterol
# rd _ full_hypo _ hdl_cholesterol_30760.0.0                             HDL_Chol
# rd _ full_hypo _ ldl_direct_30780.0.0                                  LDL_Chol
# rd _ full_hypo _ triglycerides_30870.0.0                               Triglycerides
# rd _ full_hypo _ systolic_blood_pressure_automated_reading_4080.0.1    Systolic_BP
# rd _ full_hypo _ diastolic_blood_pressure_automated_reading_4079.0.1   Diastolic_BP
