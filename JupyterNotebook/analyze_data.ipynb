# %%
library(ggplot2)

# %%
ad_rois_high <- "scratch//tractoflow_hcp_dwi/linear_regression/ad_data_high_thr.csv"
ad_data_high <- read.table(ad_rois_high, sep=',', quote='"', header=T)
hypo <- c("ad_anterior_hypothalamic_area", "ad_arcuate_hypothalamic_nucleus", "ad_dorsomedial_hypothalamic_nucleus", "ad_lateral_hypothalamus", "ad_mammillary_bodies", "ad_paraventricular_nucleus", "ad_periventricular_hypothalamic_nucleus", "ad_posterior_hypotahalamic_nucleus", "ad_suprachiasmatic_hypothalamic_nucleus", "ad_supraoptic_hypothalamic_nucleus", "ad_tuberomammillary_hypothalamic_nucleus", "ad_ventromedial_hypothalamus")
ad_data_high$full_hypo <- rowMeans(ad_data_high[, hypo], na.rm = TRUE)
lm <- lm(full_hypo ~ BMI+Age_in_Yrs+Gender, data=ad_data_high)
summary <- summary(lm)
summary
point_count <- nrow(ad_data_high)
ggplot(ad_data_high, aes(x = BMI, y = full_hypo)) +
  geom_point(color = "blue") +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "red") +
  geom_text(aes(x = max(BMI), y = max(full_hypo)),
            label = paste("N =", point_count),
            hjust = 1, vjust = 1, color = "black") +
  labs(title = "Linear Regression of High Threshold AD in the Hypothalamus", x = "BMI", y = "Average Values")
sum(is.na(ad_data_high))
ad_rois_high <- "scratch//tractoflow_hcp_dwi/linear_regression/with_outliers/ad_data_high_thr.csv"
ad_data_high <- read.table(ad_rois_high, sep=',', quote='"', header=T)
hypo <- c("ad_anterior_hypothalamic_area", "ad_arcuate_hypothalamic_nucleus", "ad_dorsomedial_hypothalamic_nucleus", "ad_lateral_hypothalamus", "ad_mammillary_bodies", "ad_paraventricular_nucleus", "ad_periventricular_hypothalamic_nucleus", "ad_posterior_hypotahalamic_nucleus", "ad_suprachiasmatic_hypothalamic_nucleus", "ad_supraoptic_hypothalamic_nucleus", "ad_tuberomammillary_hypothalamic_nucleus", "ad_ventromedial_hypothalamus")
ad_data_high$full_hypo <- rowMeans(ad_data_high[, hypo], na.rm = TRUE)
lm <- lm(full_hypo ~ BMI+Age_in_Yrs+Gender, data=ad_data_high)
summary <- summary(lm)
summary
point_count <- nrow(ad_data_high)
ggplot(ad_data_high, aes(x = BMI, y = full_hypo)) +
  geom_point(color = "blue") +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "red") +
  geom_text(aes(x = max(BMI), y = max(full_hypo)),
            label = paste("N =", point_count),
            hjust = 1, vjust = 1, color = "black") +
  labs(title = "Linear Regression of High Threshold AD in the Hypothalamus", x = "BMI", y = "Average Values")
sum(is.na(ad_data_high))
# Out:
# Call:
# lm(formula = full_hypo ~ BMI + Age_in_Yrs + Gender, data = ad_data_high)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0034395 -0.0015510 -0.0001406  0.0012871  0.0078416
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.034e-02  5.180e-04  19.967   <2e-16 ***
# BMI         -1.294e-05  1.087e-05  -1.191    0.234
# Age_in_Yrs  -1.957e-05  1.544e-05  -1.267    0.205
# GenderM     -4.356e-05  1.137e-04  -0.383    0.702
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.001798 on 1060 degrees of freedom
#   (1 observation deleted due to missingness)
# Multiple R-squared:  0.003182,	Adjusted R-squared:  0.0003608
# F-statistic: 1.128 on 3 and 1060 DF,  p-value: 0.3367
# Warning message:
# “Removed 1 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 1 rows containing missing values (`geom_point()`).”
# Warning message:
# ...

# %%
fa_rois_high <- "scratch//tractoflow_hcp_dwi/linear_regression/with_outliers/fa_data_high_thr.csv"
fa_data_high <- read.table(fa_rois_high, sep=',', quote='"', header=T)
hypo <- c("fa_anterior_hypothalamic_area", "fa_arcuate_hypothalamic_nucleus", "fa_dorsomedial_hypothalamic_nucleus", "fa_lateral_hypothalamus", "fa_mammillary_bodies", "fa_paraventricular_nucleus", "fa_periventricular_hypothalamic_nucleus", "fa_posterior_hypotahalamic_nucleus", "fa_suprachiasmatic_hypothalamic_nucleus", "fa_supraoptic_hypothalamic_nucleus", "fa_tuberomammillary_hypothalamic_nucleus", "fa_ventromedial_hypothalamus")
fa_data_high$full_hypo <- rowMeans(fa_data_high[, hypo], na.rm = TRUE)
lm <- lm(full_hypo ~ BMI+Age_in_Yrs+Gender, data=fa_data_high)
summary <- summary(lm)
summary
point_count <- nrow(fa_data_high)
ggplot(fa_data_high, aes(x = BMI, y = full_hypo)) +
  geom_point(color = "blue") +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "red") +
  geom_text(aes(x = max(BMI), y = max(full_hypo)),
            label = paste("N =", point_count),
            hjust = 1, vjust = 1, color = "black") +
  labs(title = "Linear Regression of High Threshold FA in the Hypothalamus", x = "BMI", y = "Average Values")
for (j in 6:(length(fa_data_high)-1)) { # 
    Q3=as.numeric(quantile(fa_data_high[j],0.75, na.rm=TRUE))
    Q1=as.numeric(quantile(fa_data_high[j],0.25, na.rm=TRUE))
    upper=Q3+(2.2*(Q3-Q1))
    lower=Q1-(2.2*(Q3-Q1))
    print(upper)
    print(lower)
    fa_data_high[j][fa_data_high[j]<lower]=NA
    fa_data_high[j][fa_data_high[j]>upper]=NA
}
fa_rois_high <- "scratch//tractoflow_hcp_dwi/linear_regression/fa_data_high_thr.csv"
fa_data_high <- read.table(fa_rois_high, sep=',', quote='"', header=T)
hypo <- c("fa_anterior_hypothalamic_area", "fa_arcuate_hypothalamic_nucleus", "fa_dorsomedial_hypothalamic_nucleus", "fa_lateral_hypothalamus", "fa_mammillary_bodies", "fa_paraventricular_nucleus", "fa_periventricular_hypothalamic_nucleus", "fa_posterior_hypotahalamic_nucleus", "fa_suprachiasmatic_hypothalamic_nucleus", "fa_supraoptic_hypothalamic_nucleus", "fa_tuberomammillary_hypothalamic_nucleus", "fa_ventromedial_hypothalamus")
fa_data_high$full_hypo <- rowMeans(fa_data_high[, hypo], na.rm = TRUE)
lm <- lm(full_hypo ~ BMI+Age_in_Yrs+Gender, data=fa_data_high)
summary <- summary(lm)
summary
point_count <- nrow(fa_data_high)
ggplot(fa_data_high, aes(x = BMI, y = full_hypo)) +
  geom_point(color = "blue") +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "red") +
  geom_text(aes(x = max(BMI), y = max(full_hypo)),
            label = paste("N =", point_count),
            hjust = 1, vjust = 1, color = "black") +
  labs(title = "Linear Regression of High Threshold FA in the Hypothalamus", x = "BMI", y = "Average Values")
for (j in 6:(length(fa_data_high)-1)) { # 
    Q3=as.numeric(quantile(fa_data_high[j],0.75, na.rm=TRUE))
    Q1=as.numeric(quantile(fa_data_high[j],0.25, na.rm=TRUE))
    upper=Q3+(2.2*(Q3-Q1))
    lower=Q1-(2.2*(Q3-Q1))
    print(upper)
    print(lower)
    fa_data_high[j][fa_data_high[j]<lower]=NA
    fa_data_high[j][fa_data_high[j]>upper]=NA
}
# Out:
# Call:
# lm(formula = full_hypo ~ BMI + Age_in_Yrs + Gender, data = fa_data_high)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.62133 -0.14882 -0.00672  0.13570  0.73924
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.9089549  0.0599319  48.538   <2e-16 ***
# BMI          0.0005727  0.0012574   0.455   0.6489
# Age_in_Yrs  -0.0042578  0.0017864  -2.383   0.0173 *
# GenderM     -0.1840824  0.0131543 -13.994   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.208 on 1060 degrees of freedom
#   (1 observation deleted due to missingness)
# Multiple R-squared:  0.1566,	Adjusted R-squared:  0.1542
# F-statistic: 65.62 on 3 and 1060 DF,  p-value: < 2.2e-16
# Warning message:
# “Removed 1 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 1 rows containing missing values (`geom_point()`).”
# Warning message:
# ...

# %%
md_rois_high <- "scratch//tractoflow_hcp_dwi/linear_regression/without_outliers_correct//md_data_high_thr.csv"
md_data_high <- read.table(md_rois_high, sep=',', quote='"', header=T)
hypo <- c("md_anterior_hypothalamic_area", "md_arcuate_hypothalamic_nucleus", "md_dorsomedial_hypothalamic_nucleus", "md_lateral_hypothalamus", "md_mammillary_bodies", "md_paraventricular_nucleus", "md_periventricular_hypothalamic_nucleus", "md_posterior_hypotahalamic_nucleus", "md_suprachiasmatic_hypothalamic_nucleus", "md_supraoptic_hypothalamic_nucleus", "md_tuberomammillary_hypothalamic_nucleus", "md_ventromedial_hypothalamus")
sum(is.na(md_data_high))
md_data_high$full_hypo <- rowMeans(md_data_high[, hypo], na.rm = TRUE)
lm <- lm(full_hypo ~ BMI+Age_in_Yrs+Gender, data=md_data_high)
summary <- summary(lm)
summary
point_count_1 <- nrow(md_data_high)
ggplot(md_data_high, aes(x = BMI, y = full_hypo)) +
  geom_point(color = "blue") +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "red") +
  geom_text(aes(x = max(BMI), y = max(full_hypo)),
            label = paste("N =", point_count_1),
            hjust = 1, vjust = 1, color = "black") +
  labs(title = "Linear Regression of High Threshold MD in the Hypothalamus", x = "BMI", y = "Average Values")
for (j in 6:(length(md_data_high))) { # 
    Q3=as.numeric(quantile(md_data_high[j],0.75, na.rm=TRUE))
    Q1=as.numeric(quantile(md_data_high[j],0.25, na.rm=TRUE))
    upper=Q3+(2.2*(Q3-Q1))
    lower=Q1-(2.2*(Q3-Q1))
    md_data_high[j][md_data_high[j]<lower]=NA
    md_data_high[j][md_data_high[j]>upper]=NA
}
sum(is.na(md_data_high))
md_data_high$full_hypo <- rowMeans(md_data_high[, hypo], na.rm = TRUE)
lm <- lm(full_hypo ~ BMI+Age_in_Yrs+Gender, data=md_data_high)
summary <- summary(lm)
summary
point_count_2 <- nrow(md_data_high)
ggplot(md_data_high, aes(x = BMI, y = full_hypo)) +
  geom_point(color = "blue") +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "red") +
  geom_text(aes(x = max(BMI), y = max(full_hypo)),
            label = paste("N =", point_count_2),
            hjust = 1, vjust = 1, color = "black") +
  labs(title = "Linear Regression of High Threshold MD in the Hypothalamus", x = "BMI", y = "Average Values")
# Out:
# [1] 4599
# Call:
# lm(formula = full_hypo ~ BMI + Age_in_Yrs + Gender, data = md_data_high)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0035147 -0.0006964 -0.0001221  0.0006622  0.0048637
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  8.676e-03  3.167e-04  27.397  < 2e-16 ***
# BMI         -2.527e-06  6.644e-06  -0.380  0.70381
# Age_in_Yrs  -5.279e-06  9.440e-06  -0.559  0.57615
# GenderM     -1.838e-04  6.951e-05  -2.644  0.00832 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.001099 on 1060 degrees of freedom
#   (1 observation deleted due to missingness)
# Multiple R-squared:  0.006893,	Adjusted R-squared:  0.004082
# F-statistic: 2.452 on 3 and 1060 DF,  p-value: 0.06195
# Warning message:
# “Removed 1 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 1 rows containing missing values (`geom_point()`).”
# ...

# %%
rd_rois_high <- "scratch//tractoflow_hcp_dwi/linear_regression//rd_data_high_thr.csv"
rd_data_high <- read.table(rd_rois_high, sep=',', quote='"', header=T)
hypo <- c("rd_anterior_hypothalamic_area", "rd_arcuate_hypothalamic_nucleus", "rd_dorsal_periventricular_hypothalamic_nucleus", "rd_dorsomedial_hypothalamic_nucleus", "rd_lateral_hypothalamus", "rd_mammillary_bodies", "rd_medial_preoptic_nucleus", "rd_paraventricular_nucleus", "rd_periventricular_hypothalamic_nucleus", "rd_posterior_hypothalamic_nucleus", "rd_suprachiasmatic_hypothalamic_nucleus", "rd_supraoptic_hypothalamic_nucleus", "rd_tuberomammillary_hypothalamic_nucleus", "rd_ventromedial_hypothalamus")
for (j in 6:(length(rd_data_high)-1)) { # 
    Q3=as.numeric(quantile(rd_data_high[j],0.75, na.rm=TRUE))
    Q1=as.numeric(quantile(rd_data_high[j],0.25, na.rm=TRUE))
    upper=Q3+(2.2*(Q3-Q1))
    lower=Q1-(2.2*(Q3-Q1))
    rd_data_high[j][rd_data_high[j]<lower]=NA
    rd_data_high[j][rd_data_high[j]>upper]=NA
}
rd_data_high$full_hypo <- rowMeans(rd_data_high[, hypo], na.rm = TRUE)
lm <- lm(full_hypo ~ BMI+Age_in_Yrs+Gender, data=rd_data_high)
summary <- summary(lm)
summary
point_count <- nrow(rd_data_high)
ggplot(rd_data_high, aes(x = BMI, y = full_hypo)) +
  geom_point(color = "blue") +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "red") +
  geom_text(aes(x = max(BMI), y = max(full_hypo)),
            label = paste("N =", point_count),
            hjust = 1, vjust = 1, color = "black") +
  labs(title = "Linear Regression of High Threshold RD in the Hypothalamus", x = "BMI", y = "Average Values")
# Out:
# Call:
# lm(formula = full_hypo ~ BMI + Age_in_Yrs + Gender, data = rd_data_high)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -7.866e-05 -1.714e-05  7.890e-07  1.619e-05  8.297e-05
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  6.529e-04  7.327e-06  89.103  < 2e-16 ***
# BMI         -3.429e-07  1.537e-07  -2.230  0.02593 *
# Age_in_Yrs  -8.026e-07  2.184e-07  -3.675  0.00025 ***
# GenderM     -3.596e-06  1.608e-06  -2.236  0.02555 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.544e-05 on 1060 degrees of freedom
#   (1 observation deleted due to missingness)
# Multiple R-squared:  0.02114,	Adjusted R-squared:  0.01837
# F-statistic: 7.632 on 3 and 1060 DF,  p-value: 4.749e-05
# Warning message:
# “Removed 1 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 1 rows containing missing values (`geom_point()`).”
# Warning message:
# ...

# %%
ad_rois_low <- "scratch//tractoflow_hcp_dwi/linear_regression//ad_data_low_thr.csv"
ad_data_low <- read.table(ad_rois_low, sep=',', quote='"', header=T)
hypo <- c("ad_anterior_hypothalamic_area", "ad_arcuate_hypothalamic_nucleus", "ad_dorsal_periventricular_hypothalamic_nucleus", "ad_dorsomedial_hypothalamic_nucleus", "ad_lateral_hypothalamus", "ad_mammillary_bodies", "ad_medial_preoptic_nucleus", "ad_paraventricular_nucleus", "ad_periventricular_hypothalamic_nucelus", "ad_posterior_hypothalamic_nucleus", "ad_suprachiasmatic_hypothalamic_nucleus", "ad_supraoptic_hypothalamic_nucleus", "ad_tuberomammillary_hypothalamic_nucleus", "ad_ventromedial_hypothalamus", "ad_full_hypo")
for (j in 6:(length(ad_data_low))) { # 
    Q3=as.numeric(quantile(ad_data_low[j],0.75, na.rm=TRUE))
    Q1=as.numeric(quantile(ad_data_low[j],0.25, na.rm=TRUE))
    upper=Q3+(2.2*(Q3-Q1))
    lower=Q1-(2.2*(Q3-Q1))
    ad_data_low[j][ad_data_low[j]<lower]=NA
    ad_data_low[j][ad_data_low[j]>upper]=NA
}
lm <- lm(ad_full_hypo ~ BMI+Age_in_Yrs+Gender, data=ad_data_low)
summary <- summary(lm)
summary
point_count <- nrow(ad_data_low)
ggplot(ad_data_low, aes(x = BMI, y = ad_full_hypo)) +
  geom_point(color = "blue") +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "red") +
  geom_text(aes(x = max(BMI), y = max(ad_full_hypo)),
            label = paste("N =", point_count),
            hjust = 1, vjust = 1, color = "black") +
  labs(title = "Linear Regression of Low Threshold AD in the Hypothalamus", x = "BMI", y = "Average Values")

ad_rois_low <- "scratch//tractoflow_hcp_dwi/linear_regression/with_outliers/ad_data_low_thr.csv"
ad_data_low <- read.table(ad_rois_low, sep=',', quote='"', header=T)
hypo <- c("ad_anterior_hypothalamic_area", "ad_arcuate_hypothalamic_nucleus", "ad_dorsal_periventricular_hypothalamic_nucleus", "ad_dorsomedial_hypothalamic_nucleus", "ad_lateral_hypothalamus", "ad_mammillary_bodies", "ad_medial_preoptic_nucleus", "ad_paraventricular_nucleus", "ad_periventricular_hypothalamic_nucelus", "ad_posterior_hypothalamic_nucleus", "ad_suprachiasmatic_hypothalamic_nucleus", "ad_supraoptic_hypothalamic_nucleus", "ad_tuberomammillary_hypothalamic_nucleus", "ad_ventromedial_hypothalamus", "ad_full_hypo")
for (j in 6:(length(ad_data_low))) { # 
    Q3=as.numeric(quantile(ad_data_low[j],0.75, na.rm=TRUE))
    Q1=as.numeric(quantile(ad_data_low[j],0.25, na.rm=TRUE))
    upper=Q3+(2.2*(Q3-Q1))
    lower=Q1-(2.2*(Q3-Q1))
    ad_data_low[j][ad_data_low[j]<lower]=NA
    ad_data_low[j][ad_data_low[j]>upper]=NA
}
lm <- lm(ad_full_hypo ~ BMI+Age_in_Yrs+Gender, data=ad_data_low)
summary <- summary(lm)
summary
point_count <- nrow(ad_data_low)
ggplot(ad_data_low, aes(x = BMI, y = ad_full_hypo)) +
  geom_point(color = "blue") +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "red") +
  geom_text(aes(x = max(BMI), y = max(ad_full_hypo)),
            label = paste("N =", point_count),
            hjust = 1, vjust = 1, color = "black") +
  labs(title = "Linear Regression of Low Threshold AD in the Hypothalamus", x = "BMI", y = "Average Values")
# Out:
# Call:
# lm(formula = ad_full_hypo ~ BMI + Age_in_Yrs + Gender, data = ad_data_low)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -1.104e-04 -1.903e-05  1.197e-06  1.982e-05  9.072e-05
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  9.557e-04  9.774e-06  97.788  < 2e-16 ***
# BMI         -9.466e-07  2.037e-07  -4.648 3.89e-06 ***
# Age_in_Yrs  -2.050e-06  2.893e-07  -7.084 2.92e-12 ***
# GenderM     -3.022e-05  2.162e-06 -13.977  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.055e-05 on 856 degrees of freedom
#   (205 observations deleted due to missingness)
# Multiple R-squared:  0.2294,	Adjusted R-squared:  0.2267
# F-statistic: 84.96 on 3 and 856 DF,  p-value: < 2.2e-16
# Warning message:
# “Removed 205 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 205 rows containing missing values (`geom_point()`).”
# ...

# %%
fa_rois_low <- "scratch//tractoflow_hcp_dwi/linear_regression//fa_data_low_thr.csv"
fa_data_low <- read.table(fa_rois_low, sep=',', quote='"', header=T)
hypo <- c("fa_anterior_hypothalamic_area", "fa_arcuate_hypothalamic_nucleus", "fa_dorsal_periventricular_hypothalamic_nucleus", "fa_dorsomedial_hypothalamic_nucleus", "fa_lateral_hypothalamus", "fa_mammillary_bodies", "fa_medial_preoptic_nucleus", "fa_paraventricular_nucleus", "fa_periventricular_hypothalamic_nucelus", "fa_posterior_hypothalamic_nucleus", "fa_suprachiasmatic_hypothalamic_nucleus", "fa_supraoptic_hypothalamic_nucleus", "fa_tuberomammillary_hypothalamic_nucleus", "fa_ventromedial_hypothalamus", "fa_full_hypo")
for (j in 6:(length(fa_data_low))) { # 
    Q3=as.numeric(quantile(fa_data_low[j],0.75, na.rm=TRUE))
    Q1=as.numeric(quantile(fa_data_low[j],0.25, na.rm=TRUE))
    upper=Q3+(2.2*(Q3-Q1))
    lower=Q1-(2.2*(Q3-Q1))
    fa_data_low[j][fa_data_low[j]<lower]=NA
    fa_data_low[j][fa_data_low[j]>upper]=NA
}
lm <- lm(fa_full_hypo ~ BMI+Age_in_Yrs+Gender, data=fa_data_low)
summary <- summary(lm)
summary
point_count <- nrow(fa_data_low)
ggplot(fa_data_low, aes(x = BMI, y = fa_full_hypo)) +
  geom_point(color = "blue") +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "red") +
  geom_text(aes(x = max(BMI), y = max(fa_full_hypo)),
            label = paste("N =", point_count),
            hjust = 1, vjust = 1, color = "black") +
  labs(title = "Linear Regression of Low Threshold FA in the Hypothalamus", x = "BMI", y = "Average Values")
# Out:
# Call:
# lm(formula = fa_full_hypo ~ BMI + Age_in_Yrs + Gender, data = fa_data_low)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.051419 -0.010409 -0.000821  0.010043  0.048703
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.254e-01  4.463e-03  72.914  < 2e-16 ***
# BMI         -2.925e-04  9.364e-05  -3.124  0.00183 **
# Age_in_Yrs  -8.502e-05  1.330e-04  -0.639  0.52290
# GenderM     -1.733e-02  9.796e-04 -17.691  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01549 on 1060 degrees of freedom
#   (1 observation deleted due to missingness)
# Multiple R-squared:  0.2448,	Adjusted R-squared:  0.2427
# F-statistic: 114.6 on 3 and 1060 DF,  p-value: < 2.2e-16
# Warning message:
# “Removed 1 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 1 rows containing missing values (`geom_point()`).”
# Warning message:
# ...

# %%
md_rois_low <- "scratch//tractoflow_hcp_dwi/linear_regression//md_data_low_thr.csv"
md_data_low <- read.table(md_rois_low, sep=',', quote='"', header=T)
hypo <- c("md_anterior_hypothalamic_area", "md_arcuate_hypothalamic_nucleus", "md_dorsal_periventricular_hypothalamic_nucleus", "md_dorsomedial_hypothalamic_nucleus", "md_lateral_hypothalamus", "md_mammillary_bodies", "md_medial_preoptic_nucleus", "md_paraventricular_nucleus", "md_periventricular_hypothalamic_nucelus", "md_posterior_hypothalamic_nucleus", "md_suprachiasmatic_hypothalamic_nucleus", "md_supraoptic_hypothalamic_nucleus", "md_tuberomammillary_hypothalamic_nucleus", "md_ventromedial_hypothalamus", "md_full_hypo")
for (j in 6:(length(md_data_low))) { # 
    Q3=as.numeric(quantile(md_data_low[j],0.75, na.rm=TRUE))
    Q1=as.numeric(quantile(md_data_low[j],0.25, na.rm=TRUE))
    upper=Q3+(2.2*(Q3-Q1))
    lower=Q1-(2.2*(Q3-Q1))
    md_data_low[j][md_data_low[j]<lower]=NA
    md_data_low[j][md_data_low[j]>upper]=NA
}
lm <- lm(md_full_hypo ~ BMI+Age_in_Yrs+Gender, data=md_data_low)
summary <- summary(lm)
summary
point_count <- nrow(md_data_low)
ggplot(md_data_low, aes(x = BMI, y = md_full_hypo)) +
  geom_point(color = "blue") +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "red") +
  geom_text(aes(x = max(BMI), y = max(md_full_hypo)),
            label = paste("N =", point_count),
            hjust = 1, vjust = 1, color = "black") +
  labs(title = "Linear Regression of Low Threshold MD in the Hypothalamus", x = "BMI", y = "Average Values")
# Out:
# Call:
# lm(formula = md_full_hypo ~ BMI + Age_in_Yrs + Gender, data = md_data_low)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -7.915e-05 -1.552e-05 -1.200e-08  1.573e-05  8.293e-05
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  7.093e-04  7.005e-06 101.254  < 2e-16 ***
# BMI         -5.377e-07  1.468e-07  -3.662 0.000262 ***
# Age_in_Yrs  -1.442e-06  2.089e-07  -6.901 8.87e-12 ***
# GenderM     -1.219e-05  1.539e-06  -7.921 5.94e-15 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.429e-05 on 1057 degrees of freedom
#   (4 observations deleted due to missingness)
# Multiple R-squared:  0.09678,	Adjusted R-squared:  0.09422
# F-statistic: 37.75 on 3 and 1057 DF,  p-value: < 2.2e-16
# Warning message:
# “Removed 4 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_point()`).”
# ...

# %%
rd_rois_low <- "scratch//tractoflow_hcp_dwi/linear_regression//rd_data_low_thr.csv"
rd_data_low <- read.table(rd_rois_low, sep=',', quote='"', header=T)
hypo <- c("rd_anterior_hypothalamic_area", "rd_arcuate_hypothalamic_nucleus", "rd_dorsal_periventricular_hypothalamic_nucleus", "rd_dorsomedial_hypothalamic_nucleus", "rd_lateral_hypothalamus", "rd_mammillary_bodies", "rd_medial_preoptic_nucleus", "rd_paraventricular_nucleus", "rd_periventricular_hypothalamic_nucelus", "rd_posterior_hypothalamic_nucleus", "rd_suprachiasmatic_hypothalamic_nucleus", "rd_supraoptic_hypothalamic_nucleus", "rd_tuberomammillary_hypothalamic_nucleus", "rd_ventromedial_hypothalamus", "rd_full_hypo")
for (j in 6:(length(rd_data_low))) { # 
    Q3=as.numeric(quantile(rd_data_low[j],0.75, na.rm=TRUE))
    Q1=as.numeric(quantile(rd_data_low[j],0.25, na.rm=TRUE))
    upper=Q3+(2.2*(Q3-Q1))
    lower=Q1-(2.2*(Q3-Q1))
    rd_data_low[j][rd_data_low[j]<lower]=NA
    rd_data_low[j][rd_data_low[j]>upper]=NA
}
lm <- lm(rd_full_hypo ~ BMI+Age_in_Yrs+Gender, data=rd_data_low)
summary <- summary(lm)
summary
point_count <- nrow(rd_data_low)
ggplot(rd_data_low, aes(x = BMI, y = rd_full_hypo)) +
  geom_point(color = "blue") +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "red") +
  geom_text(aes(x = max(BMI), y = max(rd_full_hypo)),
            label = paste("N =", point_count),
            hjust = 1, vjust = 1, color = "black") +
  labs(title = "Linear Regression of Low Threshold RD in the Hypothalamus", x = "BMI", y = "Average Values")
rd_rois_low <- "scratch//tractoflow_hcp_dwi/linear_regression/with_outliers/rd_data_low_thr.csv"
rd_data_low <- read.table(rd_rois_low, sep=',', quote='"', header=T)
hypo <- c("rd_anterior_hypothalamic_area", "rd_arcuate_hypothalamic_nucleus", "rd_dorsal_periventricular_hypothalamic_nucleus", "rd_dorsomedial_hypothalamic_nucleus", "rd_lateral_hypothalamus", "rd_mammillary_bodies", "rd_medial_preoptic_nucleus", "rd_paraventricular_nucleus", "rd_periventricular_hypothalamic_nucelus", "rd_posterior_hypothalamic_nucleus", "rd_suprachiasmatic_hypothalamic_nucleus", "rd_supraoptic_hypothalamic_nucleus", "rd_tuberomammillary_hypothalamic_nucleus", "rd_ventromedial_hypothalamus", "rd_full_hypo")
for (j in 6:(length(rd_data_low))) { # 
    Q3=as.numeric(quantile(rd_data_low[j],0.75, na.rm=TRUE))
    Q1=as.numeric(quantile(rd_data_low[j],0.25, na.rm=TRUE))
    upper=Q3+(2.2*(Q3-Q1))
    lower=Q1-(2.2*(Q3-Q1))
    rd_data_low[j][rd_data_low[j]<lower]=NA
    rd_data_low[j][rd_data_low[j]>upper]=NA
}
lm <- lm(rd_full_hypo ~ BMI+Age_in_Yrs+Gender, data=rd_data_low)
summary <- summary(lm)
summary
point_count <- nrow(rd_data_low)
ggplot(rd_data_low, aes(x = BMI, y = rd_full_hypo)) +
  geom_point(color = "blue") +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "red") +
  geom_text(aes(x = max(BMI), y = max(rd_full_hypo)),
            label = paste("N =", point_count),
            hjust = 1, vjust = 1, color = "black") +
  labs(title = "Linear Regression of Low Threshold RD in the Hypothalamus", x = "BMI", y = "Average Values")
# Out:
# Call:
# lm(formula = rd_full_hypo ~ BMI + Age_in_Yrs + Gender, data = rd_data_low)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -7.677e-05 -1.469e-05  2.430e-07  1.438e-05  7.050e-05
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  5.876e-04  6.801e-06  86.409  < 2e-16 ***
# BMI         -3.178e-07  1.435e-07  -2.215   0.0270 *
# Age_in_Yrs  -1.178e-06  2.020e-07  -5.831 7.34e-09 ***
# GenderM     -3.233e-06  1.482e-06  -2.181   0.0294 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.324e-05 on 1038 degrees of freedom
#   (23 observations deleted due to missingness)
# Multiple R-squared:  0.0397,	Adjusted R-squared:  0.03693
# F-statistic:  14.3 on 3 and 1038 DF,  p-value: 3.878e-09
# Warning message:
# “Removed 23 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 23 rows containing missing values (`geom_point()`).”
# ...
